# %%
# http://mnemstudio.org/neural-networks-kohonen-self-organizing-maps.htm
# https://www.saedsayad.com/clustering_som.htm
# Packages and libraries used in this program
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset with labels
raw_data = np.load('Alphabets.npy').astype(float)
labels = np.load('Alphabet_labels.npy')
alphabets =  np.array(['C','I','O','P','S','U','X','Z'])

# %%
# Number of neurons (1-dimensional)
M = 625

# Dimension of the input patterns
N = raw_data.shape[1]

# Total number of input patterns
P = raw_data.shape[0]

learning_rate = 0.6

R = 0

MAX_ITERATIONS = 100

MAX_WEIGHT_DIFF = 0.0001

DECAY_FACTOR = 0.96

RADIUS_REDUCTION_STEP = 20

# %%
# Normalize input vectors
sc = MinMaxScaler(feature_range = (0, 1))
data = sc.fit_transform(raw_data)

# %%
# Step 1: Initialization of each node’s weights with a random number between 0 and 1
weight = np.random.rand(N,M)
print("Initial weights:")
print(weight)

initial_weight = weight
last_weight = weight

for iteration in range(MAX_ITERATIONS):
    print("\r\nIteration:", iteration)
    
    # Step 2: Choosing a random input patterns ordering
    random_ordering = np.arange(P)
    np.random.shuffle(random_ordering)
    print("Random input patterns ordering:", random_ordering)

    # For each input pattern do the steps 3-5
    for p in random_ordering:
        
        print("Pattern index:", p)
        
        # Step 3: Calculating the Best Matching Unit (BMU)

        # initialize distance vector
        distance_vector = np.zeros(M)
    
        # calculate distance of each weight from each input pattern
        for j in range(M):
            for i in range(N):
                distance_vector[j] = distance_vector[j] + (weight[i,j] - data[p,i])**2
                
        #print("distance_vector", distance_vector)

        # Step 4: find index j such that distance_vector[j] is a minimum
        min_distance_index = np.argmin(distance_vector)
        
        #print("min_distance_index", min_distance_index)
        
        # Step 5: Update weights for all units j within a specified neighberhood of min_distance_index and for all i
        # calculate neighborhood borders
        begin_j = min_distance_index - R
        if (begin_j < 0):
            begin_j = 0
        
        end_j = min_distance_index + R
        if (end_j > M):
            end_j = M
            
        #print("neighberhood", begin_j, end_j)
        
        for j in range(begin_j, end_j):
            for i in range(N):
                weight[i,j] = weight[i,j] + learning_rate * (data[p,i] - weight[i,j])
    
    
    print("Updated weights:")
    print(weight)


    # Step 6: Update learning rate
    learning_rate = DECAY_FACTOR * learning_rate
    print("Learning rate:", learning_rate)
    
    # Step 7: Reduce radius of topological neighborhood at specified times
    if (iteration % RADIUS_REDUCTION_STEP):
        if R > 0 :
            R = R - 1
        print("Neighborhood radius:", R)
    
    
    # Step 8: Test stopping condition
    weight_diff = np.amax(np.abs(weight - last_weight))
    
    print("weight_diff:", weight_diff)
    
    if (weight_diff < MAX_WEIGHT_DIFF):
        break
        
    last_weight = weight
    # end of for loop
# Out:
# Initial weights:
# [[0.00426465 0.87654383 0.72063779 ... 0.08479562 0.98137279 0.58256539]
#  [0.2310008  0.16707614 0.02830018 ... 0.68509223 0.84196684 0.6015581 ]
#  [0.15090281 0.39393003 0.16255975 ... 0.50041238 0.45643967 0.46651945]
#  ...
#  [0.63670362 0.91570931 0.6866171  ... 0.13792174 0.70198117 0.82011448]
#  [0.06034284 0.86855464 0.03897398 ... 0.55758048 0.64184294 0.42296552]
#  [0.51782651 0.08693629 0.92598476 ... 0.86402027 0.71851123 0.95541586]]
#
# Iteration: 0
# Random input patterns ordering: [284 408 260 480 358 137  22  98 465 285 272 350 254 419 131 140  81 440
#   27 332 314 387  14  43 159 472 401 212 414 240 484 177 232 172 195  25
#  277 360 499  36 239 470 481  59 266 439 382 287 153 348  70 402 245 392
#  116 371 251  41 182 474 217 222  88 453 346 400 313  56 393 433 286 167
#  323 416 193 201 452 133 215 411 331 238  92 276   0 450 369 365 318 492
#   84 298 469  44 213  87 340 164 444 275 351  55   6   5 119 432 250 320
#  125 165 214  31  18 363  86 375 173 227  61 136 122 366 410 176 152 121
#  476 242 343 184 135 247 328  72 120 207 395 204 198  45 166 127 362 417
#  303 455 228 169 197  38 255 280 486  91 372 229 294 155 347   4 209 203
#  430  32 353 326 258  62 123  77  73  93 206 156  46 269  15 154  64 355
#  367 388 132 435 191 124  80 447 431 231 138  96 374 199 333  78 497 426
#  246  68  47 359 143 179 407 142 134 398 216 175  60 310 108 301 158 356
#  187 192 394 100  16 373 178 110 464 261  94 117  58 150 463 282  53 128
#  129 376 459 337 267 423 491 288  21 317  26 293 385 147 478 399 461 149
#    3  57 428 377  75 378 296 273 460 456 130 292 103  52 321 220 112 458
#  148 270 202 196 325 345 230 237 221  13 278 354 224 475 304 101 397 268
#  161   9 329 144 485 252  90  37 185 113 115 309  76 488 473  24 174 307
#  264 253 409 391 107   2 118 146 180 445 422 218 412 300 257 312  10 368
#  383 487 406 205 259 405 424 330  34 341 336 479 357 160   1  82 283  83
#  200 338 370 297 420 315  66  11 190  23 211 295 490 305 436 274 322 380
#  446 226  33 219 162 210 342 477  71 344 208 496 157 434 489  30  67 335
#  316 188 379 235 334 349  35   7 494  40 289 105 364 139  48 449 471 361
#  462 233 104 466 441 223 352 495 256 418 189 302 262 109 381  69 324  17
#  126 443 244 265  74 389  65 483 327 415 249   8  28 306 438 181  50 168
#  386  97  99 421 194 319 339 186 114 281 404  51  63 413 468 102 482 163
#  243 437  12 279  39  79 467 171  20 145 448 141  49 442 396 308 170 234
#  429  42  85 241 425 225 236  95 493 384 451  54  19 403 106 263 427  89
#  457 271 151 291 111 299 183  29 290 248 454 390 311 498]
# Pattern index: 284
# Pattern index: 408
# Pattern index: 260
# Pattern index: 480
# Pattern index: 358
# Pattern index: 137
# Pattern index: 22
# Pattern index: 98
# Pattern index: 465
# Pattern index: 285
# Pattern index: 272
# Pattern index: 350
# Pattern index: 254
# Pattern index: 419
# Pattern index: 131
# Pattern index: 140
# Pattern index: 81
# Pattern index: 440
# Pattern index: 27
# Pattern index: 332
# Pattern index: 314
# Pattern index: 387
# Pattern index: 14
# Pattern index: 43
# Pattern index: 159
# Pattern index: 472
# Pattern index: 401
# Pattern index: 212
# Pattern index: 414
# Pattern index: 240
# Pattern index: 484
# Pattern index: 177
# Pattern index: 232
# Pattern index: 172
# Pattern index: 195
# Pattern index: 25
# Pattern index: 277
# Pattern index: 360
# Pattern index: 499
# Pattern index: 36
# Pattern index: 239
# Pattern index: 470
# Pattern index: 481
# Pattern index: 59
# Pattern index: 266
# Pattern index: 439
# Pattern index: 382
# Pattern index: 287
# Pattern index: 153
# Pattern index: 348
# Pattern index: 70
# Pattern index: 402
# Pattern index: 245
# Pattern index: 392
# Pattern index: 116
# Pattern index: 371
# Pattern index: 251
# Pattern index: 41
# Pattern index: 182
# Pattern index: 474
# Pattern index: 217
# Pattern index: 222
# Pattern index: 88
# Pattern index: 453
# Pattern index: 346
# Pattern index: 400
# Pattern index: 313
# Pattern index: 56
# Pattern index: 393
# Pattern index: 433
# Pattern index: 286
# Pattern index: 167
# Pattern index: 323
# Pattern index: 416
# Pattern index: 193
# Pattern index: 201
# Pattern index: 452
# Pattern index: 133
# Pattern index: 215
# Pattern index: 411
# Pattern index: 331
# Pattern index: 238
# Pattern index: 92
# Pattern index: 276
# Pattern index: 0
# Pattern index: 450
# Pattern index: 369
# Pattern index: 365
# Pattern index: 318
# Pattern index: 492
# Pattern index: 84
# Pattern index: 298
# Pattern index: 469
# Pattern index: 44
# Pattern index: 213
# Pattern index: 87
# Pattern index: 340
# Pattern index: 164
# Pattern index: 444
# Pattern index: 275
# Pattern index: 351
# Pattern index: 55
# Pattern index: 6
# Pattern index: 5
# Pattern index: 119
# Pattern index: 432
# Pattern index: 250
# Pattern index: 320
# Pattern index: 125
# Pattern index: 165
# Pattern index: 214
# Pattern index: 31
# Pattern index: 18
# Pattern index: 363
# Pattern index: 86
# Pattern index: 375
# Pattern index: 173
# Pattern index: 227
# Pattern index: 61
# Pattern index: 136
# Pattern index: 122
# Pattern index: 366
# Pattern index: 410
# Pattern index: 176
# Pattern index: 152
# Pattern index: 121
# Pattern index: 476
# Pattern index: 242
# Pattern index: 343
# Pattern index: 184
# Pattern index: 135
# Pattern index: 247
# Pattern index: 328
# Pattern index: 72
# Pattern index: 120
# Pattern index: 207
# Pattern index: 395
# Pattern index: 204
# Pattern index: 198
# Pattern index: 45
# Pattern index: 166
# Pattern index: 127
# Pattern index: 362
# Pattern index: 417
# Pattern index: 303
# Pattern index: 455
# Pattern index: 228
# Pattern index: 169
# Pattern index: 197
# Pattern index: 38
# Pattern index: 255
# Pattern index: 280
# Pattern index: 486
# Pattern index: 91
# Pattern index: 372
# Pattern index: 229
# Pattern index: 294
# Pattern index: 155
# Pattern index: 347
# Pattern index: 4
# Pattern index: 209
# Pattern index: 203
# Pattern index: 430
# Pattern index: 32
# Pattern index: 353
# Pattern index: 326
# Pattern index: 258
# Pattern index: 62
# Pattern index: 123
# Pattern index: 77
# Pattern index: 73
# Pattern index: 93
# Pattern index: 206
# Pattern index: 156
# Pattern index: 46
# Pattern index: 269
# Pattern index: 15
# Pattern index: 154
# Pattern index: 64
# Pattern index: 355
# Pattern index: 367
# Pattern index: 388
# Pattern index: 132
# Pattern index: 435
# Pattern index: 191
# Pattern index: 124
# Pattern index: 80
# Pattern index: 447
# Pattern index: 431
# Pattern index: 231
# Pattern index: 138
# Pattern index: 96
# Pattern index: 374
# Pattern index: 199
# Pattern index: 333
# Pattern index: 78
# Pattern index: 497
# Pattern index: 426
# Pattern index: 246
# Pattern index: 68
# Pattern index: 47
# Pattern index: 359
# Pattern index: 143
# Pattern index: 179
# Pattern index: 407
# Pattern index: 142
# Pattern index: 134
# Pattern index: 398
# Pattern index: 216
# Pattern index: 175
# Pattern index: 60
# Pattern index: 310
# Pattern index: 108
# Pattern index: 301
# Pattern index: 158
# Pattern index: 356
# Pattern index: 187
# Pattern index: 192
# Pattern index: 394
# Pattern index: 100
# Pattern index: 16
# Pattern index: 373
# Pattern index: 178
# Pattern index: 110
# Pattern index: 464
# Pattern index: 261
# Pattern index: 94
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e9ca67af5e40> in <module>
#      28         for j in range(M):
#      29             for i in range(N):
# ---> 30                 distance_vector[j] = distance_vector[j] + (weight[i,j] - data[p,i])**2
#      31
#      32         #print("distance_vector", distance_vector)
#
# KeyboardInterrupt:

# %%
print(weight.shape)

# %%
clustered_patterns = np.zeros((P, N+1))
original_data = sc.inverse_transform(data)

for p in range(P):

    distance_vector = np.zeros(M)

    # calculate distance of each weight from each input pattern
    for j in range(M):
        for i in range(N):
            distance_vector[j] = distance_vector[j] + (weight[i,j] - data[p,i])**2

    # find index j such that distance_vector[j] is a minimum
    min_distance_index = np.argmin(distance_vector)
    
    clustered_patterns[p,0:N] = original_data[p]
    clustered_patterns[p,N] = min_distance_index

# %%
for p in range(P):
    plt.imshow(clustered_patterns[p,0:N].reshape(28,28))
    #print(clustered_patterns[p,0:N])
    print(clustered_patterns[p,N])
    plt.show()

#print(clustered_inputs)
