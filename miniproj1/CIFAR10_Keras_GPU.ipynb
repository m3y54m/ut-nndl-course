# %% [markdown]
# # CIFAR 10 Classification: GPU Version
#
# The goal of this notebook is to implement a simple conv net to classify CIFAR10 images using Colab GPU and compare its training time against GPU on local workstation and <a href="https://colab.research.google.com/drive/1rP91Q5L1mPOVt7FcKkqFJSIMZrBtDawO">Colab TPU</a>.

# %%
from time import time
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf

# %%
# check tensorflow version, we want the one that support eager mode
tf.__version__
# Out:
# '1.12.0'

# %%
# Check if eager execution mode is on
tf.executing_eagerly()
# Out:
# False

# %% [markdown]
# # Dataset
#
# Load CIFAR10 dataset and split the training set into train and validation set

# %%
from tensorflow.keras.datasets import cifar10, mnist

(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
print('x_train_full shape: {}, y_train_full.shape: {}'
      .format(x_train_full.shape, y_train_full.shape))
print('x_test shape: {}, y_test.shape: {}'.format(x_test.shape, y_test.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 32s 0us/step
# x_train_full shape: (50000, 32, 32, 3), y_train_full.shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3), y_test.shape: (10000, 1)

# %%
train_count = y_train_full.shape[0]
test_count = y_test.shape[0]
y_train_full = y_train_full.reshape(train_count,)
y_test = y_test.reshape(test_count,)
print('y_train_full shape: {}, y_test shape: {}'
      .format(y_train_full.shape, y_test.shape))
# Out:
# y_train_full shape: (50000,), y_test shape: (10000,)

# %%
# create validation set
split = 0.2
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.2, random_state=42)
print('x_train: {}, y_train: {}, x_val: {}, y_val: {}'
      .format(x_train.shape, y_train.shape, x_val.shape, y_val.shape))
# Out:
# x_train: (40000, 32, 32, 3), y_train: (40000,), x_val: (10000, 32, 32, 3), y_val: (10000,)

# %% [markdown]
# Lets plot 25 random images to get some idea about the dataset

# %%
# pick 25 random images and plot
idxs = np.random.randint(x_train.shape[0], size=25)
images = x_train[idxs]
labels = y_train[idxs]
classnames = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
fig, axes = plt.subplots(5,5, figsize=(8,9))
for i, ax in enumerate(axes.flat):
  ax.imshow(images[i])
  ax.axis('off')
  idx = labels[i]
  ax.set_title(classnames[idx])
  
plt.show()

# %%
def train_gen(batch_size):
  while True:
    offset = np.random.randint(0, x_train.shape[0] - batch_size)
    yield x_train[offset:offset+batch_size], y_train[offset:offset + batch_size]

# %% [markdown]
# # Build a model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(32,32,3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(10, activation='relu'))
model.add(tf.keras.layers.Activation('softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 10, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 111,946
# Trainable params: 111,498
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# # Train
#
# Train the model

# %%
model.compile(
    optimizer=tf.train.AdamOptimizer(learning_rate=1e-3, ),
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['sparse_categorical_accuracy']
)

# %%
batch_size=1024
start = time()
history = model.fit_generator(
    train_gen(batch_size), epochs=25, 
    steps_per_epoch=np.ceil(x_train.shape[0]/batch_size),
    validation_data = (x_val, y_val),
)
end = time()
# Out:
# Epoch 1/25
# 40/40 [==============================] - 8s 199ms/step - loss: 2.2921 - sparse_categorical_accuracy: 0.2287 - val_loss: 3.0874 - val_sparse_categorical_accuracy: 0.1187
# Epoch 2/25
# 40/40 [==============================] - 3s 78ms/step - loss: 1.8270 - sparse_categorical_accuracy: 0.3702 - val_loss: 2.2163 - val_sparse_categorical_accuracy: 0.2236
# Epoch 3/25
# 40/40 [==============================] - 3s 78ms/step - loss: 1.5096 - sparse_categorical_accuracy: 0.4731 - val_loss: 1.7623 - val_sparse_categorical_accuracy: 0.3467
# Epoch 4/25
# 40/40 [==============================] - 3s 79ms/step - loss: 1.3055 - sparse_categorical_accuracy: 0.5473 - val_loss: 1.6567 - val_sparse_categorical_accuracy: 0.3895
# Epoch 5/25
# 40/40 [==============================] - 3s 79ms/step - loss: 1.1650 - sparse_categorical_accuracy: 0.5998 - val_loss: 1.3945 - val_sparse_categorical_accuracy: 0.4936
# Epoch 6/25
# 40/40 [==============================] - 3s 79ms/step - loss: 1.0626 - sparse_categorical_accuracy: 0.6311 - val_loss: 1.3876 - val_sparse_categorical_accuracy: 0.5043
# Epoch 7/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.9921 - sparse_categorical_accuracy: 0.6576 - val_loss: 1.3849 - val_sparse_categorical_accuracy: 0.5071
# Epoch 8/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.9172 - sparse_categorical_accuracy: 0.6841 - val_loss: 1.0253 - val_sparse_categorical_accuracy: 0.6378
# Epoch 9/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.8591 - sparse_categorical_accuracy: 0.7065 - val_loss: 1.0635 - val_sparse_categorical_accuracy: 0.6314
# Epoch 10/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.8047 - sparse_categorical_accuracy: 0.7232 - val_loss: 1.0312 - val_sparse_categorical_accuracy: 0.6399
# Epoch 11/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.7441 - sparse_categorical_accuracy: 0.7464 - val_loss: 0.9552 - val_sparse_categorical_accuracy: 0.6654
# Epoch 12/25
# 40/40 [==============================] - 3s 80ms/step - loss: 0.7177 - sparse_categorical_accuracy: 0.7536 - val_loss: 0.9648 - val_sparse_categorical_accuracy: 0.6654
# Epoch 13/25
# 40/40 [==============================] - 3s 80ms/step - loss: 0.6531 - sparse_categorical_accuracy: 0.7763 - val_loss: 0.9870 - val_sparse_categorical_accuracy: 0.6614
# Epoch 14/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.6554 - sparse_categorical_accuracy: 0.7769 - val_loss: 1.0521 - val_sparse_categorical_accuracy: 0.6630
# Epoch 15/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.5968 - sparse_categorical_accuracy: 0.7949 - val_loss: 1.0181 - val_sparse_categorical_accuracy: 0.6686
# Epoch 16/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.5836 - sparse_categorical_accuracy: 0.8025 - val_loss: 0.9392 - val_sparse_categorical_accuracy: 0.6915
# Epoch 17/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.5454 - sparse_categorical_accuracy: 0.8136 - val_loss: 0.9408 - val_sparse_categorical_accuracy: 0.6935
# Epoch 18/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.5308 - sparse_categorical_accuracy: 0.8157 - val_loss: 0.9516 - val_sparse_categorical_accuracy: 0.6981
# Epoch 19/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4989 - sparse_categorical_accuracy: 0.8264 - val_loss: 0.9937 - val_sparse_categorical_accuracy: 0.6924
# Epoch 20/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4536 - sparse_categorical_accuracy: 0.8423 - val_loss: 1.1181 - val_sparse_categorical_accuracy: 0.6768
# Epoch 21/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4436 - sparse_categorical_accuracy: 0.8489 - val_loss: 1.0461 - val_sparse_categorical_accuracy: 0.6985
# Epoch 22/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4114 - sparse_categorical_accuracy: 0.8586 - val_loss: 1.0302 - val_sparse_categorical_accuracy: 0.7039
# Epoch 23/25
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3817 - sparse_categorical_accuracy: 0.8683 - val_loss: 1.0163 - val_sparse_categorical_accuracy: 0.7067
# Epoch 24/25
# 40/40 [==============================] - 3s 78ms/step - loss: 0.3924 - sparse_categorical_accuracy: 0.8634 - val_loss: 1.0678 - val_sparse_categorical_accuracy: 0.6927
# Epoch 25/25
# 40/40 [==============================] - 3s 78ms/step - loss: 0.3421 - sparse_categorical_accuracy: 0.8816 - val_loss: 1.1429 - val_sparse_categorical_accuracy: 0.6877

# %%
print('Total training time {} seconds'.format(end - start))
# Out:
# Total training time 84.5101706981659 seconds

# %%
def plot(losses, accuracies, subplot_title):
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,4))
  
  ax1.plot(losses)
  ax1.set_xlabel('Epochs')
  ax1.set_ylabel('Loss')
  ax1.set_title(subplot_title[0])
  
  ax2.plot(accuracies)
  ax2.set_xlabel('Epochs')
  ax2.set_ylabel('Accuracy')
  ax2.set_title(subplot_title[1])
    
  plt.show()

# %% [markdown]
# ### Plot Loss and Accuracy

# %%
# Training
plot(history.history['loss'], 
     history.history['sparse_categorical_accuracy'], 
     subplot_title=['Training Loss', 'Training Accuracy']
    )

# %%
# Validation
plot(history.history['val_loss'], 
     history.history['val_sparse_categorical_accuracy'], 
     subplot_title=['Validation Loss', 'Validation Accuracy']
    )

# %% [markdown]
# # Test accuracy
#
# Next, we plot the model predictions on test set

# %%
idxs = np.random.randint(x_test.shape[0], size=25)
images = x_test[idxs]
true_labels = y_test[idxs]

preds = np.argmax(model.predict(images), axis=1)

# %%
fig, axes = plt.subplots(5,5, figsize=(8,9))
for i, ax in enumerate(axes.flat):
  ax.imshow(images[i])
  ax.axis('off')
  idx = preds[i]
  color = 'g' if idx == true_labels[i] else 'r'
  ax.set_title(classnames[idx], color=color)

plt.show()

# %% [markdown]
# Next, you can see how to train the model on TPU <a href="https://colab.research.google.com/drive/1rP91Q5L1mPOVt7FcKkqFJSIMZrBtDawO">here</a>
