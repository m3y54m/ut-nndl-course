# %% [markdown]
# <a href="https://colab.research.google.com/github/m3y54m/ut-nndl-course/blob/master/CIFAR10_Keras_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR 10 Classification: GPU Version
#
# The goal of this notebook is to implement a simple conv net to classify CIFAR10 images using Colab GPU and compare its training time against GPU on local workstation and <a href="https://colab.research.google.com/drive/1rP91Q5L1mPOVt7FcKkqFJSIMZrBtDawO">Colab TPU</a>.

# %%
from time import time
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf

# %%
# check tensorflow version, we want the one that support eager mode
tf.__version__
# Out:
# '1.11.0'

# %%
# Check if eager execution mode is on
tf.executing_eagerly()
# Out:
# False

# %% [markdown]
# # Dataset
#
# Load CIFAR10 dataset and split the training set into train and validation set

# %%
from tensorflow.keras.datasets import cifar10, mnist

(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
print('x_train_full shape: {}, y_train_full.shape: {}'
      .format(x_train_full.shape, y_train_full.shape))
print('x_test shape: {}, y_test.shape: {}'.format(x_test.shape, y_test.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 31s 0us/step
# x_train_full shape: (50000, 32, 32, 3), y_train_full.shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3), y_test.shape: (10000, 1)

# %%
y_train_full = y_train_full.reshape(y_train_full.shape[0],)
y_test = y_test.reshape(y_test.shape[0],)
print('y_train_full shape: {}, y_test shape: {}'
      .format(y_train_full.shape, y_test.shape))
# Out:
# y_train_full shape: (50000,), y_test shape: (10000,)

# %%
# create validation set
split = 0.2
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.2, random_state=42)
print('x_train: {}, y_train: {}, x_val: {}, y_val: {}'
      .format(x_train.shape, y_train.shape, x_val.shape, y_val.shape))
# Out:
# x_train: (40000, 32, 32, 3), y_train: (40000,), x_val: (10000, 32, 32, 3), y_val: (10000,)

# %% [markdown]
# Lets plot 25 random images to get some idea about the dataset

# %%
# pick 25 random images and plot
idxs = np.random.randint(x_train.shape[0], size=25)
images = x_train[idxs]
labels = y_train[idxs]
classnames = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
fig, axes = plt.subplots(5,5, figsize=(8,9))
for i, ax in enumerate(axes.flat):
  ax.imshow(images[i])
  ax.axis('off')
  idx = labels[i]
  ax.set_title(classnames[idx])
  
plt.show()

# %%
def train_gen(batch_size):
  while True:
    offset = np.random.randint(0, x_train.shape[0] - batch_size)
    yield x_train[offset:offset+batch_size], y_train[offset:offset + batch_size]

# %% [markdown]
# # Build a model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(32,32,3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(10, activation='relu'))
model.add(tf.keras.layers.Activation('softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 10, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 111,946
# Trainable params: 111,498
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# # Train
#
# Train the model

# %%
model.compile(
    optimizer=tf.train.AdamOptimizer(learning_rate=1e-3, ),
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['sparse_categorical_accuracy']
)

# %%
batch_size=1024
start = time()
history = model.fit_generator(
    train_gen(batch_size), epochs=25, 
    steps_per_epoch=np.ceil(x_train.shape[0]/batch_size),
    validation_data = (x_val, y_val),
)
end = time()
# Out:
# Epoch 1/25
# 40/40 [==============================] - 6s 157ms/step - loss: 2.1893 - sparse_categorical_accuracy: 0.2272 - val_loss: 2.2476 - val_sparse_categorical_accuracy: 0.2086
# Epoch 2/25
# 40/40 [==============================] - 3s 83ms/step - loss: 1.7102 - sparse_categorical_accuracy: 0.4076 - val_loss: 1.9849 - val_sparse_categorical_accuracy: 0.3244
# Epoch 3/25
# 40/40 [==============================] - 3s 83ms/step - loss: 1.4227 - sparse_categorical_accuracy: 0.5067 - val_loss: 1.6027 - val_sparse_categorical_accuracy: 0.4294
# Epoch 4/25
# 40/40 [==============================] - 3s 83ms/step - loss: 1.2460 - sparse_categorical_accuracy: 0.5635 - val_loss: 1.6415 - val_sparse_categorical_accuracy: 0.4365
# Epoch 5/25
# 40/40 [==============================] - 3s 84ms/step - loss: 1.1386 - sparse_categorical_accuracy: 0.6006 - val_loss: 1.2951 - val_sparse_categorical_accuracy: 0.5513
# Epoch 6/25
# 40/40 [==============================] - 3s 84ms/step - loss: 1.0566 - sparse_categorical_accuracy: 0.6302 - val_loss: 1.1133 - val_sparse_categorical_accuracy: 0.6091
# Epoch 7/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.9728 - sparse_categorical_accuracy: 0.6613 - val_loss: 1.1408 - val_sparse_categorical_accuracy: 0.5936
# Epoch 8/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.9268 - sparse_categorical_accuracy: 0.6773 - val_loss: 1.0471 - val_sparse_categorical_accuracy: 0.6339
# Epoch 9/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.8443 - sparse_categorical_accuracy: 0.7098 - val_loss: 1.1990 - val_sparse_categorical_accuracy: 0.5926
# Epoch 10/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.8164 - sparse_categorical_accuracy: 0.7192 - val_loss: 1.0335 - val_sparse_categorical_accuracy: 0.6485
# Epoch 11/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.7589 - sparse_categorical_accuracy: 0.7369 - val_loss: 1.1013 - val_sparse_categorical_accuracy: 0.6293
# Epoch 12/25
# 40/40 [==============================] - 3s 83ms/step - loss: 0.7218 - sparse_categorical_accuracy: 0.7505 - val_loss: 1.0409 - val_sparse_categorical_accuracy: 0.6589
# Epoch 13/25
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6937 - sparse_categorical_accuracy: 0.7604 - val_loss: 0.9748 - val_sparse_categorical_accuracy: 0.6735
# Epoch 14/25
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6356 - sparse_categorical_accuracy: 0.7776 - val_loss: 1.3458 - val_sparse_categorical_accuracy: 0.5797
# Epoch 15/25
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6051 - sparse_categorical_accuracy: 0.7917 - val_loss: 1.1677 - val_sparse_categorical_accuracy: 0.6393
# Epoch 16/25
# 40/40 [==============================] - 3s 83ms/step - loss: 0.5996 - sparse_categorical_accuracy: 0.7939 - val_loss: 1.0276 - val_sparse_categorical_accuracy: 0.6712
# Epoch 17/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.5259 - sparse_categorical_accuracy: 0.8198 - val_loss: 1.0496 - val_sparse_categorical_accuracy: 0.6758
# Epoch 18/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.4909 - sparse_categorical_accuracy: 0.8284 - val_loss: 1.1136 - val_sparse_categorical_accuracy: 0.6663
# Epoch 19/25
# 40/40 [==============================] - 3s 83ms/step - loss: 0.4809 - sparse_categorical_accuracy: 0.8359 - val_loss: 1.1080 - val_sparse_categorical_accuracy: 0.6671
# Epoch 20/25
# 40/40 [==============================] - 3s 83ms/step - loss: 0.4516 - sparse_categorical_accuracy: 0.8471 - val_loss: 1.3912 - val_sparse_categorical_accuracy: 0.6294
# Epoch 21/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.4362 - sparse_categorical_accuracy: 0.8500 - val_loss: 1.0793 - val_sparse_categorical_accuracy: 0.6867
# Epoch 22/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.4275 - sparse_categorical_accuracy: 0.8529 - val_loss: 1.1084 - val_sparse_categorical_accuracy: 0.6920
# Epoch 23/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.3981 - sparse_categorical_accuracy: 0.8620 - val_loss: 1.1715 - val_sparse_categorical_accuracy: 0.6741
# Epoch 24/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.3629 - sparse_categorical_accuracy: 0.8769 - val_loss: 1.2024 - val_sparse_categorical_accuracy: 0.6783
# Epoch 25/25
# 40/40 [==============================] - 3s 84ms/step - loss: 0.3349 - sparse_categorical_accuracy: 0.8856 - val_loss: 1.1638 - val_sparse_categorical_accuracy: 0.6835

# %%
print('Total training time {} seconds'.format(end - start))
# Out:
# Total training time 86.58456611633301 seconds

# %%
def plot(losses, accuracies, subplot_title):
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,4))
  
  ax1.plot(losses)
  ax1.set_xlabel('Epochs')
  ax1.set_ylabel('Loss')
  ax1.set_title(subplot_title[0])
  
  ax2.plot(accuracies)
  ax2.set_xlabel('Epochs')
  ax2.set_ylabel('Accuracy')
  ax2.set_title(subplot_title[1])
    
  plt.show()

# %% [markdown]
# ### Plot Loss and Accuracy

# %%
# Training
plot(history.history['loss'], 
     history.history['sparse_categorical_accuracy'], 
     subplot_title=['Training Loss', 'Training Accuracy']
    )

# %%
# Validation
plot(history.history['val_loss'], 
     history.history['val_sparse_categorical_accuracy'], 
     subplot_title=['Validation Loss', 'Validation Accuracy']
    )

# %% [markdown]
# # Test accuracy
#
# Next, we plot the model predictions on test set

# %%
idxs = np.random.randint(x_test.shape[0], size=25)
images = x_test[idxs]
true_labels = y_test[idxs]

preds = np.argmax(model.predict(images), axis=1)

# %%
fig, axes = plt.subplots(5,5, figsize=(8,9))
for i, ax in enumerate(axes.flat):
  ax.imshow(images[i])
  ax.axis('off')
  idx = preds[i]
  color = 'g' if idx == true_labels[i] else 'r'
  ax.set_title(classnames[idx], color=color)

plt.show()

# %% [markdown]
# Next, you can see how to train the model on TPU <a href="https://colab.research.google.com/drive/1rP91Q5L1mPOVt7FcKkqFJSIMZrBtDawO">here</a>
