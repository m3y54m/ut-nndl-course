# %% [markdown]
# <a href="https://colab.research.google.com/github/m3y54m/ut-nndl-course/blob/master/Q1_SOM_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# http://mnemstudio.org/neural-networks-kohonen-self-organizing-maps.htm
# https://www.saedsayad.com/clustering_som.htm
# Packages and libraries used in this program
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset with labels
#raw_data = np.load('Alphabets.npy').astype(float)
#labels = np.load('Alphabet_labels.npy')
alphabets =  np.array(['C','I','O','P','S','U','X','Z'])
#initial_weight = np.load('initial_weight.npy')

# %%
from google.colab import files
import io
uploaded = files.upload()
raw_data = np.load(io.BytesIO(uploaded['Alphabets.npy'])).astype(float)
uploaded = files.upload()
labels = np.load(io.BytesIO(uploaded['Alphabet_labels.npy']))
uploaded = files.upload()
initial_weight = np.load(io.BytesIO(uploaded['initial_weight.npy']))
# Out:
#      <input type="file" id="files-daf504e3-3603-44c3-8dde-4a5f1ec84c23" name="files[]" multiple disabled />
#      <output id="result-daf504e3-3603-44c3-8dde-4a5f1ec84c23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alphabets.npy to Alphabets (1).npy
#      <input type="file" id="files-2a3c9067-23e2-469e-9f16-729c278ad4bb" name="files[]" multiple disabled />
#      <output id="result-2a3c9067-23e2-469e-9f16-729c278ad4bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alphabet_labels.npy to Alphabet_labels (1).npy
#      <input type="file" id="files-bc39e7ac-eb23-48c9-80b0-7c2c589ee47d" name="files[]" multiple disabled />
#      <output id="result-bc39e7ac-eb23-48c9-80b0-7c2c589ee47d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving initial_weight.npy to initial_weight (1).npy

# %%
# Number of neurons (1-dimensional)
M = 625

# Dimension of the input patterns
N = raw_data.shape[1]

# Total number of input patterns
P = raw_data.shape[0]

learning_rate = 0.3

R = 1

MAX_EPOCHS = 100

MAX_WEIGHT_DIFF = 0.0001

DECAY_FACTOR = 0.0001

RADIUS_REDUCTION_STEP = 200

np.set_printoptions(threshold=np.nan)

# %%
# Normalize input vectors
sc = MinMaxScaler(feature_range = (0, 1))
data = sc.fit_transform(raw_data)

# %%
# Step 1: Initialization of each node’s weights with a random number between 0 and 1
#weight = 0.1 * np.random.rand(N,M)
weight = np.copy(initial_weight)
#print("Initial weights:")
#print(np.around(weight, 2))

last_weight = np.copy(weight)

for epoch in range(MAX_EPOCHS):
    print("\r\nEpoch:", epoch)
    print("Learning rate:", np.around(learning_rate, 6))
    print("Neighborhood radius:", R)
    
    # Step 2: Choosing input patterns ordering
    # use normal ordering
    pattern_ordering = np.arange(P)
    # use random ordering
    #np.random.shuffle(pattern_ordering)
    #print("Random input patterns ordering:", pattern_ordering)
    
    progress = 0
    
    # For each input pattern do the steps 3-5
    for p in pattern_ordering:
        
        progress = progress + 1
        
        #print("\r\n\tCurrent pattern index is", p, "and", np.around(progress/P*100, 2), "% of patterns has been processed in Epoch", epoch)
        
        # Step 3: Calculating the Best Matching Unit (BMU)

        # initialize distance vector
        distance_vector = np.zeros(M)
    
        # calculate distance of each weight from each input pattern
        for j in range(M):
            for i in range(N):
                distance_vector[j] = distance_vector[j] + (weight[i,j] - data[p,i])**2
                
        #print("\tdistance_vector", np.around(distance_vector, 2))

        # Step 4: find index j such that distance_vector[j] is a minimum
        min_distance_index = np.argmin(distance_vector)
        
        #print("\tmin_distance_index", min_distance_index)
        
        # Step 5: Update weights for all units j within a specified neighberhood of min_distance_index and for all i
        # calculate neighborhood borders
        begin_j = min_distance_index - R
        if (begin_j < 0):
            begin_j = 0
        
        end_j = min_distance_index + R
        if (end_j > M - 1):
            end_j = M - 1
            
        #print("neighberhood", begin_j, end_j)
        
        for j in range(begin_j, end_j + 1):
            for i in range(N):
                weight[i,j] = weight[i,j] + learning_rate * (data[p,i] - weight[i,j])

    # Step 6: Update learning rate
    learning_rate = DECAY_FACTOR * learning_rate

    # Step 7: Reduce radius of topological neighborhood at specified times
    if (epoch % RADIUS_REDUCTION_STEP):
        if R > 0 :
            R = R - 1
        
    # Step 8: Test stopping condition
    weight_diff = np.amax(np.abs(weight - last_weight))
    
    if (weight_diff < MAX_WEIGHT_DIFF):
        print("Weight change:", weight_diff, "<", MAX_WEIGHT_DIFF)
        print("Stopping condition is satisfied!")
        break
    else:
        print("Weight change:", weight_diff, ">", MAX_WEIGHT_DIFF)
    
    last_weight = np.copy(weight)
    # end of for loop
    
#print("\r\Final weights:")
#print(np.around(weight, 2))
# Out:
# Epoch: 0
# Learning rate: 0.3
# Neighborhood radius: 1
# Weight change: 0.9614941380828702 > 0.0001
#
# Epoch: 1
# Learning rate: 3e-05
# Neighborhood radius: 1
# Weight change: 0.000761134387809087 > 0.0001
#
# Epoch: 2
# Learning rate: 0.0
# Neighborhood radius: 0
# Weight change: 2.992303882454195e-08 < 0.0001
# Stopping condition is satisfied!

# %%
# associate pattern indices with clusters numbers
patterns_with_clusters = np.zeros((P, 2), dtype=int)

for p in range(P):

    distance_vector = np.zeros(M)

    # calculate distance of each weight from each input pattern
    for j in range(M):
        for i in range(N):
            distance_vector[j] = distance_vector[j] + (weight[i,j] - data[p,i])**2

    # find index j such that distance_vector[j] is a minimum
    min_distance_index = np.argmin(distance_vector)
    
    # store pattern index 
    patterns_with_clusters[p,0] = p
    # store cluster number associated with pattern 
    patterns_with_clusters[p,1] = min_distance_index

# %%
# make an array of clusters size and members
clusters_size = [0 for j in range(M)]
clusters_members = [[] for j in range(M)]
for p in range(P):
    # increment cluster size by 1
    clusters_size[patterns_with_clusters[p,1].astype(int)] = clusters_size[patterns_with_clusters[p,1].astype(int)] + 1
    # append the pattern index to cluster members list
    clusters_members[patterns_with_clusters[p,1].astype(int)].append(p)


clustered_patterns = [clusters_size, clusters_members]

# find 20 largest clusters
largest_clusters = np.asarray(clusters_size).argsort()[-20:][::-1]

print("20 Largest Clusters")
total_of_20 = 0
for j in largest_clusters:
    print("Cluster", j, "\t=>\t", clusters_size[j],"patterns.")
    total_of_20 = total_of_20 + clusters_size[j]
print("\r\nTotal", total_of_20, "patterns are in top 20 clusters.")
# Out:
# 20 Largest Clusters
# Cluster 123 	=>	 27 patterns.
# Cluster 134 	=>	 25 patterns.
# Cluster 130 	=>	 22 patterns.
# Cluster 136 	=>	 19 patterns.
# Cluster 131 	=>	 19 patterns.
# Cluster 378 	=>	 19 patterns.
# Cluster 126 	=>	 18 patterns.
# Cluster 377 	=>	 17 patterns.
# Cluster 125 	=>	 17 patterns.
# Cluster 376 	=>	 16 patterns.
# Cluster 121 	=>	 16 patterns.
# Cluster 135 	=>	 15 patterns.
# Cluster 137 	=>	 15 patterns.
# Cluster 129 	=>	 14 patterns.
# Cluster 375 	=>	 14 patterns.
# Cluster 138 	=>	 12 patterns.
# Cluster 476 	=>	 12 patterns.
# Cluster 477 	=>	 12 patterns.
# Cluster 118 	=>	 12 patterns.
# Cluster 139 	=>	 12 patterns.
#
# Total 333 patterns are in top 20 clusters.

# %%
original_data = sc.inverse_transform(data)
clusters_size = clustered_patterns[0]
clusters_members = clustered_patterns[1]
for j in largest_clusters:
    print("Cluster", j, "with", clusters_size[j],"patterns:")
    for p in clusters_members[j]:
        print("\r\n\tPattern", p, " with correct interpretation of", alphabets[labels[p]] ,"is put in cluster", j)
        #plt.imshow(original_data[p].reshape(28,28))
        #plt.show()
# Out:
# Cluster 123 with 27 patterns:
#
# 	Pattern 1  with correct interpretation of O is put in cluster 123
#
# 	Pattern 66  with correct interpretation of C is put in cluster 123
#
# 	Pattern 72  with correct interpretation of O is put in cluster 123
#
# 	Pattern 111  with correct interpretation of C is put in cluster 123
#
# 	Pattern 113  with correct interpretation of C is put in cluster 123
#
# 	Pattern 168  with correct interpretation of O is put in cluster 123
#
# 	Pattern 226  with correct interpretation of C is put in cluster 123
#
# 	Pattern 230  with correct interpretation of C is put in cluster 123
#
# 	Pattern 247  with correct interpretation of C is put in cluster 123
#
# 	Pattern 258  with correct interpretation of O is put in cluster 123
#
# 	Pattern 269  with correct interpretation of O is put in cluster 123
#
# 	Pattern 276  with correct interpretation of C is put in cluster 123
#
# 	Pattern 301  with correct interpretation of C is put in cluster 123
#
# 	Pattern 304  with correct interpretation of C is put in cluster 123
#
# 	Pattern 305  with correct interpretation of C is put in cluster 123
#
# 	Pattern 306  with correct interpretation of C is put in cluster 123
#
# 	Pattern 338  with correct interpretation of C is put in cluster 123
#
# 	Pattern 342  with correct interpretation of C is put in cluster 123
#
# 	Pattern 346  with correct interpretation of C is put in cluster 123
#
# 	Pattern 376  with correct interpretation of O is put in cluster 123
#
# 	Pattern 391  with correct interpretation of C is put in cluster 123
#
# 	Pattern 398  with correct interpretation of C is put in cluster 123
#
# 	Pattern 432  with correct interpretation of O is put in cluster 123
#
# 	Pattern 439  with correct interpretation of C is put in cluster 123
#
# 	Pattern 448  with correct interpretation of C is put in cluster 123
#
# 	Pattern 458  with correct interpretation of C is put in cluster 123
#
# 	Pattern 470  with correct interpretation of C is put in cluster 123
# Cluster 134 with 25 patterns:
#
# 	Pattern 9  with correct interpretation of I is put in cluster 134
#
# 	Pattern 31  with correct interpretation of I is put in cluster 134
#
# 	Pattern 45  with correct interpretation of I is put in cluster 134
#
# 	Pattern 59  with correct interpretation of I is put in cluster 134
#
# 	Pattern 75  with correct interpretation of I is put in cluster 134
#
# 	Pattern 80  with correct interpretation of I is put in cluster 134
#
# 	Pattern 90  with correct interpretation of I is put in cluster 134
#
# 	Pattern 114  with correct interpretation of I is put in cluster 134
#
# 	Pattern 119  with correct interpretation of I is put in cluster 134
#
# 	Pattern 192  with correct interpretation of I is put in cluster 134
#
# 	Pattern 194  with correct interpretation of I is put in cluster 134
#
# 	Pattern 207  with correct interpretation of I is put in cluster 134
#
# 	Pattern 210  with correct interpretation of I is put in cluster 134
#
# 	Pattern 220  with correct interpretation of I is put in cluster 134
#
# 	Pattern 223  with correct interpretation of I is put in cluster 134
#
# 	Pattern 268  with correct interpretation of I is put in cluster 134
#
# 	Pattern 288  with correct interpretation of I is put in cluster 134
#
# 	Pattern 330  with correct interpretation of I is put in cluster 134
#
# 	Pattern 360  with correct interpretation of P is put in cluster 134
#
# 	Pattern 377  with correct interpretation of I is put in cluster 134
#
# 	Pattern 430  with correct interpretation of I is put in cluster 134
#
# 	Pattern 440  with correct interpretation of I is put in cluster 134
#
# 	Pattern 445  with correct interpretation of I is put in cluster 134
#
# 	Pattern 483  with correct interpretation of I is put in cluster 134
#
# 	Pattern 495  with correct interpretation of I is put in cluster 134
# Cluster 130 with 22 patterns:
#
# 	Pattern 11  with correct interpretation of X is put in cluster 130
#
# 	Pattern 73  with correct interpretation of S is put in cluster 130
#
# 	Pattern 76  with correct interpretation of S is put in cluster 130
#
# 	Pattern 78  with correct interpretation of S is put in cluster 130
#
# 	Pattern 87  with correct interpretation of S is put in cluster 130
#
# 	Pattern 106  with correct interpretation of S is put in cluster 130
#
# 	Pattern 122  with correct interpretation of S is put in cluster 130
#
# 	Pattern 229  with correct interpretation of S is put in cluster 130
#
# 	Pattern 241  with correct interpretation of S is put in cluster 130
#
# 	Pattern 252  with correct interpretation of S is put in cluster 130
#
# 	Pattern 298  with correct interpretation of S is put in cluster 130
#
# 	Pattern 328  with correct interpretation of S is put in cluster 130
#
# 	Pattern 334  with correct interpretation of S is put in cluster 130
#
# 	Pattern 359  with correct interpretation of S is put in cluster 130
#
# 	Pattern 366  with correct interpretation of S is put in cluster 130
#
# 	Pattern 369  with correct interpretation of S is put in cluster 130
#
# 	Pattern 410  with correct interpretation of S is put in cluster 130
#
# 	Pattern 417  with correct interpretation of S is put in cluster 130
#
# 	Pattern 425  with correct interpretation of S is put in cluster 130
#
# 	Pattern 426  with correct interpretation of S is put in cluster 130
#
# 	Pattern 434  with correct interpretation of S is put in cluster 130
#
# 	Pattern 490  with correct interpretation of S is put in cluster 130
# Cluster 136 with 19 patterns:
#
# 	Pattern 0  with correct interpretation of P is put in cluster 136
#
# 	Pattern 12  with correct interpretation of I is put in cluster 136
#
# 	Pattern 21  with correct interpretation of P is put in cluster 136
#
# 	Pattern 47  with correct interpretation of P is put in cluster 136
#
# 	Pattern 123  with correct interpretation of X is put in cluster 136
#
# 	Pattern 140  with correct interpretation of P is put in cluster 136
#
# 	Pattern 256  with correct interpretation of I is put in cluster 136
#
# 	Pattern 267  with correct interpretation of I is put in cluster 136
#
# 	Pattern 318  with correct interpretation of I is put in cluster 136
#
# 	Pattern 326  with correct interpretation of I is put in cluster 136
#
# 	Pattern 337  with correct interpretation of O is put in cluster 136
#
# 	Pattern 401  with correct interpretation of P is put in cluster 136
#
# 	Pattern 402  with correct interpretation of I is put in cluster 136
#
# 	Pattern 404  with correct interpretation of X is put in cluster 136
#
# 	Pattern 415  with correct interpretation of I is put in cluster 136
#
# 	Pattern 422  with correct interpretation of P is put in cluster 136
#
# 	Pattern 467  with correct interpretation of I is put in cluster 136
#
# 	Pattern 472  with correct interpretation of I is put in cluster 136
#
# 	Pattern 473  with correct interpretation of X is put in cluster 136
# Cluster 131 with 19 patterns:
#
# 	Pattern 8  with correct interpretation of S is put in cluster 131
#
# 	Pattern 25  with correct interpretation of S is put in cluster 131
#
# 	Pattern 71  with correct interpretation of S is put in cluster 131
#
# 	Pattern 81  with correct interpretation of S is put in cluster 131
#
# 	Pattern 112  with correct interpretation of S is put in cluster 131
#
# 	Pattern 136  with correct interpretation of S is put in cluster 131
#
# 	Pattern 151  with correct interpretation of S is put in cluster 131
#
# 	Pattern 154  with correct interpretation of S is put in cluster 131
#
# 	Pattern 219  with correct interpretation of S is put in cluster 131
#
# 	Pattern 263  with correct interpretation of S is put in cluster 131
#
# 	Pattern 281  with correct interpretation of S is put in cluster 131
#
# 	Pattern 296  with correct interpretation of S is put in cluster 131
#
# 	Pattern 353  with correct interpretation of S is put in cluster 131
#
# 	Pattern 361  with correct interpretation of S is put in cluster 131
#
# 	Pattern 386  with correct interpretation of S is put in cluster 131
#
# 	Pattern 393  with correct interpretation of S is put in cluster 131
#
# 	Pattern 406  with correct interpretation of S is put in cluster 131
#
# 	Pattern 433  with correct interpretation of S is put in cluster 131
#
# 	Pattern 459  with correct interpretation of S is put in cluster 131
# Cluster 378 with 19 patterns:
#
# 	Pattern 16  with correct interpretation of C is put in cluster 378
#
# 	Pattern 17  with correct interpretation of P is put in cluster 378
#
# 	Pattern 18  with correct interpretation of C is put in cluster 378
#
# 	Pattern 41  with correct interpretation of P is put in cluster 378
#
# 	Pattern 50  with correct interpretation of C is put in cluster 378
#
# 	Pattern 84  with correct interpretation of P is put in cluster 378
#
# 	Pattern 85  with correct interpretation of S is put in cluster 378
#
# 	Pattern 107  with correct interpretation of O is put in cluster 378
#
# 	Pattern 235  with correct interpretation of P is put in cluster 378
#
# 	Pattern 254  with correct interpretation of U is put in cluster 378
#
# 	Pattern 255  with correct interpretation of O is put in cluster 378
#
# 	Pattern 283  with correct interpretation of P is put in cluster 378
#
# 	Pattern 300  with correct interpretation of P is put in cluster 378
#
# 	Pattern 316  with correct interpretation of C is put in cluster 378
#
# 	Pattern 370  with correct interpretation of P is put in cluster 378
#
# 	Pattern 392  with correct interpretation of U is put in cluster 378
#
# 	Pattern 443  with correct interpretation of C is put in cluster 378
#
# 	Pattern 466  with correct interpretation of O is put in cluster 378
#
# 	Pattern 475  with correct interpretation of O is put in cluster 378
# Cluster 126 with 18 patterns:
#
# 	Pattern 26  with correct interpretation of C is put in cluster 126
#
# 	Pattern 46  with correct interpretation of O is put in cluster 126
#
# 	Pattern 103  with correct interpretation of O is put in cluster 126
#
# 	Pattern 156  with correct interpretation of O is put in cluster 126
#
# 	Pattern 218  with correct interpretation of O is put in cluster 126
#
# 	Pattern 231  with correct interpretation of O is put in cluster 126
#
# 	Pattern 240  with correct interpretation of O is put in cluster 126
#
# 	Pattern 284  with correct interpretation of O is put in cluster 126
#
# 	Pattern 310  with correct interpretation of O is put in cluster 126
#
# 	Pattern 333  with correct interpretation of O is put in cluster 126
#
# 	Pattern 363  with correct interpretation of O is put in cluster 126
#
# 	Pattern 383  with correct interpretation of O is put in cluster 126
#
# 	Pattern 384  with correct interpretation of O is put in cluster 126
#
# 	Pattern 457  with correct interpretation of O is put in cluster 126
#
# 	Pattern 471  with correct interpretation of O is put in cluster 126
#
# 	Pattern 478  with correct interpretation of O is put in cluster 126
#
# 	Pattern 479  with correct interpretation of O is put in cluster 126
#
# 	Pattern 497  with correct interpretation of O is put in cluster 126
# Cluster 377 with 17 patterns:
#
# 	Pattern 20  with correct interpretation of U is put in cluster 377
#
# 	Pattern 68  with correct interpretation of U is put in cluster 377
#
# 	Pattern 89  with correct interpretation of P is put in cluster 377
#
# 	Pattern 93  with correct interpretation of U is put in cluster 377
#
# 	Pattern 130  with correct interpretation of U is put in cluster 377
#
# 	Pattern 142  with correct interpretation of O is put in cluster 377
#
# 	Pattern 159  with correct interpretation of C is put in cluster 377
#
# 	Pattern 160  with correct interpretation of U is put in cluster 377
#
# 	Pattern 173  with correct interpretation of U is put in cluster 377
#
# 	Pattern 184  with correct interpretation of O is put in cluster 377
#
# 	Pattern 193  with correct interpretation of U is put in cluster 377
#
# 	Pattern 221  with correct interpretation of O is put in cluster 377
#
# 	Pattern 228  with correct interpretation of U is put in cluster 377
#
# 	Pattern 319  with correct interpretation of U is put in cluster 377
#
# 	Pattern 324  with correct interpretation of U is put in cluster 377
#
# 	Pattern 374  with correct interpretation of U is put in cluster 377
#
# 	Pattern 451  with correct interpretation of U is put in cluster 377
# Cluster 125 with 17 patterns:
#
# 	Pattern 86  with correct interpretation of O is put in cluster 125
#
# 	Pattern 178  with correct interpretation of O is put in cluster 125
#
# 	Pattern 181  with correct interpretation of O is put in cluster 125
#
# 	Pattern 189  with correct interpretation of O is put in cluster 125
#
# 	Pattern 204  with correct interpretation of S is put in cluster 125
#
# 	Pattern 209  with correct interpretation of O is put in cluster 125
#
# 	Pattern 216  with correct interpretation of O is put in cluster 125
#
# 	Pattern 292  with correct interpretation of O is put in cluster 125
#
# 	Pattern 299  with correct interpretation of C is put in cluster 125
#
# 	Pattern 317  with correct interpretation of S is put in cluster 125
#
# 	Pattern 329  with correct interpretation of O is put in cluster 125
#
# 	Pattern 400  with correct interpretation of C is put in cluster 125
#
# 	Pattern 416  with correct interpretation of O is put in cluster 125
#
# 	Pattern 424  with correct interpretation of O is put in cluster 125
#
# 	Pattern 429  with correct interpretation of S is put in cluster 125
#
# 	Pattern 452  with correct interpretation of O is put in cluster 125
#
# 	Pattern 462  with correct interpretation of O is put in cluster 125
# Cluster 376 with 16 patterns:
#
# 	Pattern 10  with correct interpretation of U is put in cluster 376
#
# 	Pattern 15  with correct interpretation of U is put in cluster 376
#
# 	Pattern 22  with correct interpretation of U is put in cluster 376
#
# 	Pattern 51  with correct interpretation of U is put in cluster 376
#
# 	Pattern 61  with correct interpretation of U is put in cluster 376
#
# 	Pattern 88  with correct interpretation of U is put in cluster 376
#
# 	Pattern 94  with correct interpretation of U is put in cluster 376
#
# 	Pattern 99  with correct interpretation of U is put in cluster 376
#
# 	Pattern 162  with correct interpretation of U is put in cluster 376
#
# 	Pattern 206  with correct interpretation of U is put in cluster 376
#
# 	Pattern 246  with correct interpretation of U is put in cluster 376
#
# 	Pattern 257  with correct interpretation of O is put in cluster 376
#
# 	Pattern 309  with correct interpretation of U is put in cluster 376
#
# 	Pattern 372  with correct interpretation of U is put in cluster 376
#
# 	Pattern 411  with correct interpretation of U is put in cluster 376
#
# 	Pattern 485  with correct interpretation of U is put in cluster 376
# Cluster 121 with 16 patterns:
#
# 	Pattern 40  with correct interpretation of O is put in cluster 121
#
# 	Pattern 100  with correct interpretation of C is put in cluster 121
#
# 	Pattern 125  with correct interpretation of O is put in cluster 121
#
# 	Pattern 164  with correct interpretation of O is put in cluster 121
#
# 	Pattern 203  with correct interpretation of O is put in cluster 121
#
# 	Pattern 222  with correct interpretation of O is put in cluster 121
#
# 	Pattern 260  with correct interpretation of C is put in cluster 121
#
# 	Pattern 270  with correct interpretation of O is put in cluster 121
#
# 	Pattern 286  with correct interpretation of O is put in cluster 121
#
# 	Pattern 322  with correct interpretation of O is put in cluster 121
#
# 	Pattern 367  with correct interpretation of C is put in cluster 121
#
# 	Pattern 387  with correct interpretation of C is put in cluster 121
#
# 	Pattern 438  with correct interpretation of S is put in cluster 121
#
# 	Pattern 477  with correct interpretation of O is put in cluster 121
#
# 	Pattern 493  with correct interpretation of C is put in cluster 121
#
# 	Pattern 499  with correct interpretation of C is put in cluster 121
# Cluster 135 with 15 patterns:
#
# 	Pattern 14  with correct interpretation of I is put in cluster 135
#
# 	Pattern 32  with correct interpretation of X is put in cluster 135
#
# 	Pattern 53  with correct interpretation of I is put in cluster 135
#
# 	Pattern 62  with correct interpretation of I is put in cluster 135
#
# 	Pattern 67  with correct interpretation of I is put in cluster 135
#
# 	Pattern 70  with correct interpretation of I is put in cluster 135
#
# 	Pattern 131  with correct interpretation of I is put in cluster 135
#
# 	Pattern 233  with correct interpretation of I is put in cluster 135
#
# 	Pattern 250  with correct interpretation of I is put in cluster 135
#
# 	Pattern 315  with correct interpretation of I is put in cluster 135
#
# 	Pattern 323  with correct interpretation of I is put in cluster 135
#
# 	Pattern 362  with correct interpretation of I is put in cluster 135
#
# 	Pattern 394  with correct interpretation of I is put in cluster 135
#
# 	Pattern 418  with correct interpretation of I is put in cluster 135
#
# 	Pattern 460  with correct interpretation of I is put in cluster 135
# Cluster 137 with 15 patterns:
#
# 	Pattern 29  with correct interpretation of P is put in cluster 137
#
# 	Pattern 83  with correct interpretation of S is put in cluster 137
#
# 	Pattern 161  with correct interpretation of P is put in cluster 137
#
# 	Pattern 197  with correct interpretation of I is put in cluster 137
#
# 	Pattern 213  with correct interpretation of P is put in cluster 137
#
# 	Pattern 236  with correct interpretation of P is put in cluster 137
#
# 	Pattern 290  with correct interpretation of P is put in cluster 137
#
# 	Pattern 325  with correct interpretation of P is put in cluster 137
#
# 	Pattern 395  with correct interpretation of P is put in cluster 137
#
# 	Pattern 414  with correct interpretation of X is put in cluster 137
#
# 	Pattern 419  with correct interpretation of P is put in cluster 137
#
# 	Pattern 428  with correct interpretation of X is put in cluster 137
#
# 	Pattern 431  with correct interpretation of X is put in cluster 137
#
# 	Pattern 447  with correct interpretation of X is put in cluster 137
#
# 	Pattern 461  with correct interpretation of P is put in cluster 137
# Cluster 129 with 14 patterns:
#
# 	Pattern 137  with correct interpretation of P is put in cluster 129
#
# 	Pattern 238  with correct interpretation of P is put in cluster 129
#
# 	Pattern 245  with correct interpretation of P is put in cluster 129
#
# 	Pattern 253  with correct interpretation of P is put in cluster 129
#
# 	Pattern 280  with correct interpretation of P is put in cluster 129
#
# 	Pattern 347  with correct interpretation of P is put in cluster 129
#
# 	Pattern 371  with correct interpretation of P is put in cluster 129
#
# 	Pattern 380  with correct interpretation of P is put in cluster 129
#
# 	Pattern 388  with correct interpretation of P is put in cluster 129
#
# 	Pattern 413  with correct interpretation of P is put in cluster 129
#
# 	Pattern 420  with correct interpretation of P is put in cluster 129
#
# 	Pattern 446  with correct interpretation of P is put in cluster 129
#
# 	Pattern 454  with correct interpretation of P is put in cluster 129
#
# 	Pattern 481  with correct interpretation of P is put in cluster 129
# Cluster 375 with 14 patterns:
#
# 	Pattern 36  with correct interpretation of U is put in cluster 375
#
# 	Pattern 54  with correct interpretation of U is put in cluster 375
#
# 	Pattern 64  with correct interpretation of U is put in cluster 375
#
# 	Pattern 104  with correct interpretation of U is put in cluster 375
#
# 	Pattern 120  with correct interpretation of U is put in cluster 375
#
# 	Pattern 143  with correct interpretation of U is put in cluster 375
#
# 	Pattern 176  with correct interpretation of U is put in cluster 375
#
# 	Pattern 242  with correct interpretation of U is put in cluster 375
#
# 	Pattern 248  with correct interpretation of U is put in cluster 375
#
# 	Pattern 261  with correct interpretation of U is put in cluster 375
#
# 	Pattern 314  with correct interpretation of U is put in cluster 375
#
# 	Pattern 381  with correct interpretation of O is put in cluster 375
#
# 	Pattern 399  with correct interpretation of U is put in cluster 375
#
# 	Pattern 449  with correct interpretation of U is put in cluster 375
# Cluster 138 with 12 patterns:
#
# 	Pattern 13  with correct interpretation of X is put in cluster 138
#
# 	Pattern 28  with correct interpretation of Z is put in cluster 138
#
# 	Pattern 63  with correct interpretation of I is put in cluster 138
#
# 	Pattern 144  with correct interpretation of Z is put in cluster 138
#
# 	Pattern 208  with correct interpretation of X is put in cluster 138
#
# 	Pattern 265  with correct interpretation of X is put in cluster 138
#
# 	Pattern 294  with correct interpretation of I is put in cluster 138
#
# 	Pattern 341  with correct interpretation of U is put in cluster 138
#
# 	Pattern 350  with correct interpretation of P is put in cluster 138
#
# 	Pattern 385  with correct interpretation of I is put in cluster 138
#
# 	Pattern 412  with correct interpretation of X is put in cluster 138
#
# 	Pattern 444  with correct interpretation of P is put in cluster 138
# Cluster 476 with 12 patterns:
#
# 	Pattern 2  with correct interpretation of X is put in cluster 476
#
# 	Pattern 24  with correct interpretation of X is put in cluster 476
#
# 	Pattern 134  with correct interpretation of X is put in cluster 476
#
# 	Pattern 183  with correct interpretation of X is put in cluster 476
#
# 	Pattern 224  with correct interpretation of X is put in cluster 476
#
# 	Pattern 275  with correct interpretation of X is put in cluster 476
#
# 	Pattern 289  with correct interpretation of X is put in cluster 476
#
# 	Pattern 302  with correct interpretation of X is put in cluster 476
#
# 	Pattern 354  with correct interpretation of X is put in cluster 476
#
# 	Pattern 389  with correct interpretation of X is put in cluster 476
#
# 	Pattern 441  with correct interpretation of X is put in cluster 476
#
# 	Pattern 465  with correct interpretation of X is put in cluster 476
# Cluster 477 with 12 patterns:
#
# 	Pattern 23  with correct interpretation of X is put in cluster 477
#
# 	Pattern 97  with correct interpretation of X is put in cluster 477
#
# 	Pattern 98  with correct interpretation of X is put in cluster 477
#
# 	Pattern 132  with correct interpretation of Z is put in cluster 477
#
# 	Pattern 153  with correct interpretation of X is put in cluster 477
#
# 	Pattern 179  with correct interpretation of X is put in cluster 477
#
# 	Pattern 239  with correct interpretation of X is put in cluster 477
#
# 	Pattern 331  with correct interpretation of Z is put in cluster 477
#
# 	Pattern 336  with correct interpretation of X is put in cluster 477
#
# 	Pattern 368  with correct interpretation of Z is put in cluster 477
#
# 	Pattern 456  with correct interpretation of X is put in cluster 477
#
# 	Pattern 468  with correct interpretation of X is put in cluster 477
# Cluster 118 with 12 patterns:
#
# 	Pattern 7  with correct interpretation of X is put in cluster 118
#
# 	Pattern 30  with correct interpretation of Z is put in cluster 118
#
# 	Pattern 33  with correct interpretation of Z is put in cluster 118
#
# 	Pattern 55  with correct interpretation of U is put in cluster 118
#
# 	Pattern 110  with correct interpretation of C is put in cluster 118
#
# 	Pattern 116  with correct interpretation of Z is put in cluster 118
#
# 	Pattern 146  with correct interpretation of Z is put in cluster 118
#
# 	Pattern 201  with correct interpretation of C is put in cluster 118
#
# 	Pattern 211  with correct interpretation of C is put in cluster 118
#
# 	Pattern 214  with correct interpretation of Z is put in cluster 118
#
# 	Pattern 282  with correct interpretation of Z is put in cluster 118
#
# 	Pattern 469  with correct interpretation of C is put in cluster 118
# Cluster 139 with 12 patterns:
#
# 	Pattern 58  with correct interpretation of X is put in cluster 139
#
# 	Pattern 118  with correct interpretation of X is put in cluster 139
#
# 	Pattern 157  with correct interpretation of X is put in cluster 139
#
# 	Pattern 165  with correct interpretation of X is put in cluster 139
#
# 	Pattern 167  with correct interpretation of X is put in cluster 139
#
# 	Pattern 177  with correct interpretation of Z is put in cluster 139
#
# 	Pattern 212  with correct interpretation of Z is put in cluster 139
#
# 	Pattern 291  with correct interpretation of X is put in cluster 139
#
# 	Pattern 293  with correct interpretation of X is put in cluster 139
#
# 	Pattern 335  with correct interpretation of X is put in cluster 139
#
# 	Pattern 349  with correct interpretation of X is put in cluster 139
#
# 	Pattern 488  with correct interpretation of X is put in cluster 139

# %%
#np.save('initial_weight.npy', initial_weight)
#np.save('final_weight.npy', weight)
#initial_weight = np.load('initial_weight.npy')
#weight = np.load('final_weight.npy')
