# %% [markdown]
# <a href="https://colab.research.google.com/github/m3y54m/ut-nndl-course/blob/master/Q1_SOM_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# http://mnemstudio.org/neural-networks-kohonen-self-organizing-maps.htm
# https://www.saedsayad.com/clustering_som.htm
# Packages and libraries used in this program
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset with labels
#raw_data = np.load('Alphabets.npy').astype(float)
#labels = np.load('Alphabet_labels.npy')
alphabets =  np.array(['C','I','O','P','S','U','X','Z'])
#initial_weight = np.load('initial_weight.npy')

# %%
from google.colab import files
import io
uploaded = files.upload()
raw_data = np.load(io.BytesIO(uploaded['Alphabets.npy'])).astype(float)
uploaded = files.upload()
labels = np.load(io.BytesIO(uploaded['Alphabet_labels.npy']))
uploaded = files.upload()
initial_weight = np.load(io.BytesIO(uploaded['initial_weight.npy']))
# Out:
#      <input type="file" id="files-d5578a7b-7bad-4359-bfc8-f23ad8f842e8" name="files[]" multiple disabled />
#      <output id="result-d5578a7b-7bad-4359-bfc8-f23ad8f842e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alphabets.npy to Alphabets.npy
#      <input type="file" id="files-155e43df-bf02-4e96-b2cc-70f1c19a81b4" name="files[]" multiple disabled />
#      <output id="result-155e43df-bf02-4e96-b2cc-70f1c19a81b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alphabet_labels.npy to Alphabet_labels.npy
#      <input type="file" id="files-0475b944-7322-4777-a20e-1fa3933fe009" name="files[]" multiple disabled />
#      <output id="result-0475b944-7322-4777-a20e-1fa3933fe009">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving initial_weight.npy to initial_weight.npy

# %%
# Number of neurons (1-dimensional)
M = 625

# Dimension of the input patterns
N = raw_data.shape[1]

# Total number of input patterns
P = raw_data.shape[0]

learning_rate = 0.2

R = 0

MAX_EPOCHS = 100

MAX_WEIGHT_DIFF = 0.0001

DECAY_FACTOR = 0.00005

RADIUS_REDUCTION_STEP = 20

np.set_printoptions(threshold=np.nan)

# %%
# Normalize input vectors
sc = MinMaxScaler(feature_range = (0, 1))
data = sc.fit_transform(raw_data)

# %%
# Step 1: Initialization of each node’s weights with a random number between 0 and 1
#weight = 0.1 * np.random.rand(N,M)
weight = np.copy(initial_weight)
#print("Initial weights:")
#print(np.around(weight, 2))

last_weight = np.copy(weight)

for epoch in range(MAX_EPOCHS):
    print("\r\nEpoch:", epoch)
    print("Learning rate:", np.around(learning_rate, 6))
    print("Neighborhood radius:", R)
    
    # Step 2: Choosing input patterns ordering
    # use normal ordering
    pattern_ordering = np.arange(P)
    # use random ordering
    #np.random.shuffle(pattern_ordering)
    #print("Random input patterns ordering:", pattern_ordering)
    
    progress = 0
    
    # For each input pattern do the steps 3-5
    for p in pattern_ordering:
        
        progress = progress + 1
        
        #print("\r\n\tCurrent pattern index is", p, "and", np.around(progress/P*100, 2), "% of patterns has been processed in Epoch", epoch)
        
        # Step 3: Calculating the Best Matching Unit (BMU)

        # initialize distance vector
        distance_vector = np.zeros(M)
    
        # calculate distance of each weight from each input pattern
        for j in range(M):
            for i in range(N):
                distance_vector[j] = distance_vector[j] + (weight[i,j] - data[p,i])**2
                
        #print("\tdistance_vector", np.around(distance_vector, 2))

        # Step 4: find index j such that distance_vector[j] is a minimum
        min_distance_index = np.argmin(distance_vector)
        
        #print("\tmin_distance_index", min_distance_index)
        
        # Step 5: Update weights for all units j within a specified neighberhood of min_distance_index and for all i
        # calculate neighborhood borders
        begin_j = min_distance_index - R
        if (begin_j < 0):
            begin_j = 0
        
        end_j = min_distance_index + R
        if (end_j > M - 1):
            end_j = M - 1
            
        #print("neighberhood", begin_j, end_j)
        
        for j in range(begin_j, end_j + 1):
            for i in range(N):
                weight[i,j] = weight[i,j] + learning_rate * (data[p,i] - weight[i,j])

    # Step 6: Update learning rate
    learning_rate = DECAY_FACTOR * learning_rate

    # Step 7: Reduce radius of topological neighborhood at specified times
    if (epoch % RADIUS_REDUCTION_STEP):
        if R > 0 :
            R = R - 1
        
    # Step 8: Test stopping condition
    weight_diff = np.amax(np.abs(weight - last_weight))
    
    if (weight_diff < MAX_WEIGHT_DIFF):
        print("Weight change:", weight_diff, "<", MAX_WEIGHT_DIFF)
        print("Stopping condition is satisfied!")
        break
    else:
        print("Weight change:", weight_diff, ">", MAX_WEIGHT_DIFF)
    
    last_weight = np.copy(weight)
    # end of for loop
    
#print("\r\Final weights:")
#print(np.around(weight, 2))
# Out:
# Epoch: 0
# Learning rate: 0.2
# Neighborhood radius: 0
# Weight change: 0.9547342521952211 > 0.0001
#
# Epoch: 1
# Learning rate: 1e-05
# Neighborhood radius: 0
# Weight change: 0.00027588661032229567 > 0.0001
#
# Epoch: 2
# Learning rate: 0.0
# Neighborhood radius: 0
# Weight change: 1.378799774354178e-08 < 0.0001
# Stopping condition is satisfied!

# %%
# associate pattern indices with clusters numbers
patterns_with_clusters = np.zeros((P, 2), dtype=int)

for p in range(P):

    distance_vector = np.zeros(M)

    # calculate distance of each weight from each input pattern
    for j in range(M):
        for i in range(N):
            distance_vector[j] = distance_vector[j] + (weight[i,j] - data[p,i])**2

    # find index j such that distance_vector[j] is a minimum
    min_distance_index = np.argmin(distance_vector)
    
    # store pattern index 
    patterns_with_clusters[p,0] = p
    # store cluster number associated with pattern 
    patterns_with_clusters[p,1] = min_distance_index

# %%
# make an array of clusters size and members
clusters_size = [0 for j in range(M)]
clusters_members = [[] for j in range(M)]
for p in range(P):
    # increment cluster size by 1
    clusters_size[patterns_with_clusters[p,1].astype(int)] = clusters_size[patterns_with_clusters[p,1].astype(int)] + 1
    # append the pattern index to cluster members list
    clusters_members[patterns_with_clusters[p,1].astype(int)].append(p)


clustered_patterns = [clusters_size, clusters_members]

# find 20 largest clusters
largest_clusters = np.asarray(clusters_size).argsort()[-20:][::-1]

print("20 Largest Clusters")
total_of_20 = 0
for j in largest_clusters:
    print("Cluster", j, "\t=>\t", clusters_size[j],"patterns.")
    total_of_20 = total_of_20 + clusters_size[j]
print("\r\nTotal", total_of_20, "patterns are in top 20 clusters.")
# Out:
# 20 Largest Clusters
# Cluster 510 	=>	 100 patterns.
# Cluster 496 	=>	 74 patterns.
# Cluster 128 	=>	 73 patterns.
# Cluster 374 	=>	 68 patterns.
# Cluster 48 	=>	 62 patterns.
# Cluster 375 	=>	 57 patterns.
# Cluster 143 	=>	 23 patterns.
# Cluster 478 	=>	 22 patterns.
# Cluster 318 	=>	 20 patterns.
# Cluster 513 	=>	 1 patterns.
# Cluster 624 	=>	 0 patterns.
# Cluster 208 	=>	 0 patterns.
# Cluster 207 	=>	 0 patterns.
# Cluster 206 	=>	 0 patterns.
# Cluster 205 	=>	 0 patterns.
# Cluster 203 	=>	 0 patterns.
# Cluster 204 	=>	 0 patterns.
# Cluster 210 	=>	 0 patterns.
# Cluster 202 	=>	 0 patterns.
# Cluster 201 	=>	 0 patterns.
#
# Total 500 patterns are in top 20 clusters.

# %%
original_data = sc.inverse_transform(data)
clusters_size = clustered_patterns[0]
clusters_members = clustered_patterns[1]
for j in largest_clusters:
    print("Cluster", j, "with", clusters_size[j],"patterns:")
    for p in clusters_members[j]:
        print("\r\n\tPattern", p, " with correct interpretation of", alphabets[labels[p]] ,"is put in cluster", j)
        #plt.imshow(original_data[p].reshape(28,28))
        #plt.show()
# Out:
# Cluster 510 with 100 patterns:
#
# 	Pattern 5  with correct interpretation of U is put in cluster 510
#
# 	Pattern 15  with correct interpretation of U is put in cluster 510
#
# 	Pattern 22  with correct interpretation of U is put in cluster 510
#
# 	Pattern 26  with correct interpretation of C is put in cluster 510
#
# 	Pattern 36  with correct interpretation of U is put in cluster 510
#
# 	Pattern 40  with correct interpretation of O is put in cluster 510
#
# 	Pattern 42  with correct interpretation of C is put in cluster 510
#
# 	Pattern 43  with correct interpretation of C is put in cluster 510
#
# 	Pattern 46  with correct interpretation of O is put in cluster 510
#
# 	Pattern 51  with correct interpretation of U is put in cluster 510
#
# 	Pattern 54  with correct interpretation of U is put in cluster 510
#
# 	Pattern 57  with correct interpretation of C is put in cluster 510
#
# 	Pattern 61  with correct interpretation of U is put in cluster 510
#
# 	Pattern 64  with correct interpretation of U is put in cluster 510
#
# 	Pattern 86  with correct interpretation of O is put in cluster 510
#
# 	Pattern 88  with correct interpretation of U is put in cluster 510
#
# 	Pattern 93  with correct interpretation of U is put in cluster 510
#
# 	Pattern 94  with correct interpretation of U is put in cluster 510
#
# 	Pattern 100  with correct interpretation of C is put in cluster 510
#
# 	Pattern 103  with correct interpretation of O is put in cluster 510
#
# 	Pattern 125  with correct interpretation of O is put in cluster 510
#
# 	Pattern 127  with correct interpretation of Z is put in cluster 510
#
# 	Pattern 135  with correct interpretation of C is put in cluster 510
#
# 	Pattern 142  with correct interpretation of O is put in cluster 510
#
# 	Pattern 144  with correct interpretation of Z is put in cluster 510
#
# 	Pattern 148  with correct interpretation of C is put in cluster 510
#
# 	Pattern 155  with correct interpretation of C is put in cluster 510
#
# 	Pattern 156  with correct interpretation of O is put in cluster 510
#
# 	Pattern 159  with correct interpretation of C is put in cluster 510
#
# 	Pattern 162  with correct interpretation of U is put in cluster 510
#
# 	Pattern 164  with correct interpretation of O is put in cluster 510
#
# 	Pattern 170  with correct interpretation of C is put in cluster 510
#
# 	Pattern 178  with correct interpretation of O is put in cluster 510
#
# 	Pattern 180  with correct interpretation of C is put in cluster 510
#
# 	Pattern 181  with correct interpretation of O is put in cluster 510
#
# 	Pattern 184  with correct interpretation of O is put in cluster 510
#
# 	Pattern 189  with correct interpretation of O is put in cluster 510
#
# 	Pattern 203  with correct interpretation of O is put in cluster 510
#
# 	Pattern 204  with correct interpretation of S is put in cluster 510
#
# 	Pattern 206  with correct interpretation of U is put in cluster 510
#
# 	Pattern 209  with correct interpretation of O is put in cluster 510
#
# 	Pattern 216  with correct interpretation of O is put in cluster 510
#
# 	Pattern 218  with correct interpretation of O is put in cluster 510
#
# 	Pattern 231  with correct interpretation of O is put in cluster 510
#
# 	Pattern 240  with correct interpretation of O is put in cluster 510
#
# 	Pattern 248  with correct interpretation of U is put in cluster 510
#
# 	Pattern 251  with correct interpretation of U is put in cluster 510
#
# 	Pattern 257  with correct interpretation of O is put in cluster 510
#
# 	Pattern 260  with correct interpretation of C is put in cluster 510
#
# 	Pattern 270  with correct interpretation of O is put in cluster 510
#
# 	Pattern 274  with correct interpretation of C is put in cluster 510
#
# 	Pattern 284  with correct interpretation of O is put in cluster 510
#
# 	Pattern 286  with correct interpretation of O is put in cluster 510
#
# 	Pattern 292  with correct interpretation of O is put in cluster 510
#
# 	Pattern 297  with correct interpretation of Z is put in cluster 510
#
# 	Pattern 299  with correct interpretation of C is put in cluster 510
#
# 	Pattern 303  with correct interpretation of C is put in cluster 510
#
# 	Pattern 310  with correct interpretation of O is put in cluster 510
#
# 	Pattern 311  with correct interpretation of Z is put in cluster 510
#
# 	Pattern 319  with correct interpretation of U is put in cluster 510
#
# 	Pattern 322  with correct interpretation of O is put in cluster 510
#
# 	Pattern 329  with correct interpretation of O is put in cluster 510
#
# 	Pattern 333  with correct interpretation of O is put in cluster 510
#
# 	Pattern 340  with correct interpretation of O is put in cluster 510
#
# 	Pattern 351  with correct interpretation of C is put in cluster 510
#
# 	Pattern 352  with correct interpretation of O is put in cluster 510
#
# 	Pattern 358  with correct interpretation of C is put in cluster 510
#
# 	Pattern 363  with correct interpretation of O is put in cluster 510
#
# 	Pattern 372  with correct interpretation of U is put in cluster 510
#
# 	Pattern 382  with correct interpretation of O is put in cluster 510
#
# 	Pattern 383  with correct interpretation of O is put in cluster 510
#
# 	Pattern 384  with correct interpretation of O is put in cluster 510
#
# 	Pattern 387  with correct interpretation of C is put in cluster 510
#
# 	Pattern 397  with correct interpretation of C is put in cluster 510
#
# 	Pattern 399  with correct interpretation of U is put in cluster 510
#
# 	Pattern 400  with correct interpretation of C is put in cluster 510
#
# 	Pattern 403  with correct interpretation of O is put in cluster 510
#
# 	Pattern 411  with correct interpretation of U is put in cluster 510
#
# 	Pattern 416  with correct interpretation of O is put in cluster 510
#
# 	Pattern 423  with correct interpretation of C is put in cluster 510
#
# 	Pattern 424  with correct interpretation of O is put in cluster 510
#
# 	Pattern 429  with correct interpretation of S is put in cluster 510
#
# 	Pattern 438  with correct interpretation of S is put in cluster 510
#
# 	Pattern 442  with correct interpretation of U is put in cluster 510
#
# 	Pattern 449  with correct interpretation of U is put in cluster 510
#
# 	Pattern 452  with correct interpretation of O is put in cluster 510
#
# 	Pattern 453  with correct interpretation of C is put in cluster 510
#
# 	Pattern 457  with correct interpretation of O is put in cluster 510
#
# 	Pattern 462  with correct interpretation of O is put in cluster 510
#
# 	Pattern 471  with correct interpretation of O is put in cluster 510
#
# 	Pattern 474  with correct interpretation of O is put in cluster 510
#
# 	Pattern 475  with correct interpretation of O is put in cluster 510
#
# 	Pattern 477  with correct interpretation of O is put in cluster 510
#
# 	Pattern 479  with correct interpretation of O is put in cluster 510
#
# 	Pattern 484  with correct interpretation of C is put in cluster 510
#
# 	Pattern 485  with correct interpretation of U is put in cluster 510
#
# 	Pattern 493  with correct interpretation of C is put in cluster 510
#
# 	Pattern 496  with correct interpretation of C is put in cluster 510
#
# 	Pattern 497  with correct interpretation of O is put in cluster 510
#
# 	Pattern 499  with correct interpretation of C is put in cluster 510
# Cluster 496 with 74 patterns:
#
# 	Pattern 2  with correct interpretation of X is put in cluster 496
#
# 	Pattern 13  with correct interpretation of X is put in cluster 496
#
# 	Pattern 23  with correct interpretation of X is put in cluster 496
#
# 	Pattern 38  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 47  with correct interpretation of P is put in cluster 496
#
# 	Pattern 58  with correct interpretation of X is put in cluster 496
#
# 	Pattern 63  with correct interpretation of I is put in cluster 496
#
# 	Pattern 65  with correct interpretation of X is put in cluster 496
#
# 	Pattern 69  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 97  with correct interpretation of X is put in cluster 496
#
# 	Pattern 98  with correct interpretation of X is put in cluster 496
#
# 	Pattern 102  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 115  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 117  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 118  with correct interpretation of X is put in cluster 496
#
# 	Pattern 123  with correct interpretation of X is put in cluster 496
#
# 	Pattern 132  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 134  with correct interpretation of X is put in cluster 496
#
# 	Pattern 140  with correct interpretation of P is put in cluster 496
#
# 	Pattern 141  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 153  with correct interpretation of X is put in cluster 496
#
# 	Pattern 157  with correct interpretation of X is put in cluster 496
#
# 	Pattern 161  with correct interpretation of P is put in cluster 496
#
# 	Pattern 165  with correct interpretation of X is put in cluster 496
#
# 	Pattern 167  with correct interpretation of X is put in cluster 496
#
# 	Pattern 171  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 179  with correct interpretation of X is put in cluster 496
#
# 	Pattern 183  with correct interpretation of X is put in cluster 496
#
# 	Pattern 197  with correct interpretation of I is put in cluster 496
#
# 	Pattern 198  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 200  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 202  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 205  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 212  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 225  with correct interpretation of C is put in cluster 496
#
# 	Pattern 234  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 239  with correct interpretation of X is put in cluster 496
#
# 	Pattern 249  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 271  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 275  with correct interpretation of X is put in cluster 496
#
# 	Pattern 279  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 289  with correct interpretation of X is put in cluster 496
#
# 	Pattern 294  with correct interpretation of I is put in cluster 496
#
# 	Pattern 302  with correct interpretation of X is put in cluster 496
#
# 	Pattern 312  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 313  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 331  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 335  with correct interpretation of X is put in cluster 496
#
# 	Pattern 336  with correct interpretation of X is put in cluster 496
#
# 	Pattern 368  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 379  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 385  with correct interpretation of I is put in cluster 496
#
# 	Pattern 389  with correct interpretation of X is put in cluster 496
#
# 	Pattern 390  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 395  with correct interpretation of P is put in cluster 496
#
# 	Pattern 396  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 408  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 412  with correct interpretation of X is put in cluster 496
#
# 	Pattern 414  with correct interpretation of X is put in cluster 496
#
# 	Pattern 419  with correct interpretation of P is put in cluster 496
#
# 	Pattern 428  with correct interpretation of X is put in cluster 496
#
# 	Pattern 431  with correct interpretation of X is put in cluster 496
#
# 	Pattern 447  with correct interpretation of X is put in cluster 496
#
# 	Pattern 455  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 456  with correct interpretation of X is put in cluster 496
#
# 	Pattern 461  with correct interpretation of P is put in cluster 496
#
# 	Pattern 465  with correct interpretation of X is put in cluster 496
#
# 	Pattern 468  with correct interpretation of X is put in cluster 496
#
# 	Pattern 473  with correct interpretation of X is put in cluster 496
#
# 	Pattern 488  with correct interpretation of X is put in cluster 496
#
# 	Pattern 489  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 492  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 494  with correct interpretation of Z is put in cluster 496
#
# 	Pattern 498  with correct interpretation of Z is put in cluster 496
# Cluster 128 with 73 patterns:
#
# 	Pattern 1  with correct interpretation of O is put in cluster 128
#
# 	Pattern 6  with correct interpretation of U is put in cluster 128
#
# 	Pattern 10  with correct interpretation of U is put in cluster 128
#
# 	Pattern 16  with correct interpretation of C is put in cluster 128
#
# 	Pattern 19  with correct interpretation of O is put in cluster 128
#
# 	Pattern 39  with correct interpretation of C is put in cluster 128
#
# 	Pattern 48  with correct interpretation of U is put in cluster 128
#
# 	Pattern 56  with correct interpretation of C is put in cluster 128
#
# 	Pattern 60  with correct interpretation of U is put in cluster 128
#
# 	Pattern 66  with correct interpretation of C is put in cluster 128
#
# 	Pattern 68  with correct interpretation of U is put in cluster 128
#
# 	Pattern 72  with correct interpretation of O is put in cluster 128
#
# 	Pattern 73  with correct interpretation of S is put in cluster 128
#
# 	Pattern 77  with correct interpretation of C is put in cluster 128
#
# 	Pattern 82  with correct interpretation of O is put in cluster 128
#
# 	Pattern 99  with correct interpretation of U is put in cluster 128
#
# 	Pattern 104  with correct interpretation of U is put in cluster 128
#
# 	Pattern 105  with correct interpretation of C is put in cluster 128
#
# 	Pattern 111  with correct interpretation of C is put in cluster 128
#
# 	Pattern 113  with correct interpretation of C is put in cluster 128
#
# 	Pattern 120  with correct interpretation of U is put in cluster 128
#
# 	Pattern 128  with correct interpretation of C is put in cluster 128
#
# 	Pattern 130  with correct interpretation of U is put in cluster 128
#
# 	Pattern 143  with correct interpretation of U is put in cluster 128
#
# 	Pattern 150  with correct interpretation of C is put in cluster 128
#
# 	Pattern 158  with correct interpretation of U is put in cluster 128
#
# 	Pattern 168  with correct interpretation of O is put in cluster 128
#
# 	Pattern 169  with correct interpretation of Z is put in cluster 128
#
# 	Pattern 176  with correct interpretation of U is put in cluster 128
#
# 	Pattern 185  with correct interpretation of O is put in cluster 128
#
# 	Pattern 193  with correct interpretation of U is put in cluster 128
#
# 	Pattern 221  with correct interpretation of O is put in cluster 128
#
# 	Pattern 229  with correct interpretation of S is put in cluster 128
#
# 	Pattern 230  with correct interpretation of C is put in cluster 128
#
# 	Pattern 237  with correct interpretation of C is put in cluster 128
#
# 	Pattern 246  with correct interpretation of U is put in cluster 128
#
# 	Pattern 247  with correct interpretation of C is put in cluster 128
#
# 	Pattern 258  with correct interpretation of O is put in cluster 128
#
# 	Pattern 261  with correct interpretation of U is put in cluster 128
#
# 	Pattern 269  with correct interpretation of O is put in cluster 128
#
# 	Pattern 273  with correct interpretation of C is put in cluster 128
#
# 	Pattern 276  with correct interpretation of C is put in cluster 128
#
# 	Pattern 301  with correct interpretation of C is put in cluster 128
#
# 	Pattern 304  with correct interpretation of C is put in cluster 128
#
# 	Pattern 305  with correct interpretation of C is put in cluster 128
#
# 	Pattern 306  with correct interpretation of C is put in cluster 128
#
# 	Pattern 308  with correct interpretation of U is put in cluster 128
#
# 	Pattern 309  with correct interpretation of U is put in cluster 128
#
# 	Pattern 314  with correct interpretation of U is put in cluster 128
#
# 	Pattern 320  with correct interpretation of C is put in cluster 128
#
# 	Pattern 324  with correct interpretation of U is put in cluster 128
#
# 	Pattern 327  with correct interpretation of Z is put in cluster 128
#
# 	Pattern 334  with correct interpretation of S is put in cluster 128
#
# 	Pattern 338  with correct interpretation of C is put in cluster 128
#
# 	Pattern 342  with correct interpretation of C is put in cluster 128
#
# 	Pattern 344  with correct interpretation of C is put in cluster 128
#
# 	Pattern 346  with correct interpretation of C is put in cluster 128
#
# 	Pattern 357  with correct interpretation of U is put in cluster 128
#
# 	Pattern 367  with correct interpretation of C is put in cluster 128
#
# 	Pattern 376  with correct interpretation of O is put in cluster 128
#
# 	Pattern 381  with correct interpretation of O is put in cluster 128
#
# 	Pattern 391  with correct interpretation of C is put in cluster 128
#
# 	Pattern 398  with correct interpretation of C is put in cluster 128
#
# 	Pattern 407  with correct interpretation of U is put in cluster 128
#
# 	Pattern 426  with correct interpretation of S is put in cluster 128
#
# 	Pattern 432  with correct interpretation of O is put in cluster 128
#
# 	Pattern 436  with correct interpretation of U is put in cluster 128
#
# 	Pattern 437  with correct interpretation of C is put in cluster 128
#
# 	Pattern 439  with correct interpretation of C is put in cluster 128
#
# 	Pattern 448  with correct interpretation of C is put in cluster 128
#
# 	Pattern 451  with correct interpretation of U is put in cluster 128
#
# 	Pattern 458  with correct interpretation of C is put in cluster 128
#
# 	Pattern 470  with correct interpretation of C is put in cluster 128
# Cluster 374 with 68 patterns:
#
# 	Pattern 8  with correct interpretation of S is put in cluster 374
#
# 	Pattern 11  with correct interpretation of X is put in cluster 374
#
# 	Pattern 18  with correct interpretation of C is put in cluster 374
#
# 	Pattern 25  with correct interpretation of S is put in cluster 374
#
# 	Pattern 34  with correct interpretation of S is put in cluster 374
#
# 	Pattern 35  with correct interpretation of Z is put in cluster 374
#
# 	Pattern 37  with correct interpretation of S is put in cluster 374
#
# 	Pattern 49  with correct interpretation of C is put in cluster 374
#
# 	Pattern 71  with correct interpretation of S is put in cluster 374
#
# 	Pattern 76  with correct interpretation of S is put in cluster 374
#
# 	Pattern 78  with correct interpretation of S is put in cluster 374
#
# 	Pattern 81  with correct interpretation of S is put in cluster 374
#
# 	Pattern 83  with correct interpretation of S is put in cluster 374
#
# 	Pattern 87  with correct interpretation of S is put in cluster 374
#
# 	Pattern 101  with correct interpretation of S is put in cluster 374
#
# 	Pattern 106  with correct interpretation of S is put in cluster 374
#
# 	Pattern 107  with correct interpretation of O is put in cluster 374
#
# 	Pattern 112  with correct interpretation of S is put in cluster 374
#
# 	Pattern 122  with correct interpretation of S is put in cluster 374
#
# 	Pattern 136  with correct interpretation of S is put in cluster 374
#
# 	Pattern 145  with correct interpretation of Z is put in cluster 374
#
# 	Pattern 151  with correct interpretation of S is put in cluster 374
#
# 	Pattern 154  with correct interpretation of S is put in cluster 374
#
# 	Pattern 173  with correct interpretation of U is put in cluster 374
#
# 	Pattern 175  with correct interpretation of S is put in cluster 374
#
# 	Pattern 186  with correct interpretation of S is put in cluster 374
#
# 	Pattern 187  with correct interpretation of P is put in cluster 374
#
# 	Pattern 215  with correct interpretation of S is put in cluster 374
#
# 	Pattern 219  with correct interpretation of S is put in cluster 374
#
# 	Pattern 222  with correct interpretation of O is put in cluster 374
#
# 	Pattern 228  with correct interpretation of U is put in cluster 374
#
# 	Pattern 241  with correct interpretation of S is put in cluster 374
#
# 	Pattern 244  with correct interpretation of C is put in cluster 374
#
# 	Pattern 252  with correct interpretation of S is put in cluster 374
#
# 	Pattern 255  with correct interpretation of O is put in cluster 374
#
# 	Pattern 259  with correct interpretation of C is put in cluster 374
#
# 	Pattern 263  with correct interpretation of S is put in cluster 374
#
# 	Pattern 272  with correct interpretation of C is put in cluster 374
#
# 	Pattern 277  with correct interpretation of S is put in cluster 374
#
# 	Pattern 281  with correct interpretation of S is put in cluster 374
#
# 	Pattern 296  with correct interpretation of S is put in cluster 374
#
# 	Pattern 298  with correct interpretation of S is put in cluster 374
#
# 	Pattern 316  with correct interpretation of C is put in cluster 374
#
# 	Pattern 317  with correct interpretation of S is put in cluster 374
#
# 	Pattern 328  with correct interpretation of S is put in cluster 374
#
# 	Pattern 337  with correct interpretation of O is put in cluster 374
#
# 	Pattern 339  with correct interpretation of S is put in cluster 374
#
# 	Pattern 343  with correct interpretation of S is put in cluster 374
#
# 	Pattern 353  with correct interpretation of S is put in cluster 374
#
# 	Pattern 354  with correct interpretation of X is put in cluster 374
#
# 	Pattern 359  with correct interpretation of S is put in cluster 374
#
# 	Pattern 361  with correct interpretation of S is put in cluster 374
#
# 	Pattern 366  with correct interpretation of S is put in cluster 374
#
# 	Pattern 369  with correct interpretation of S is put in cluster 374
#
# 	Pattern 386  with correct interpretation of S is put in cluster 374
#
# 	Pattern 393  with correct interpretation of S is put in cluster 374
#
# 	Pattern 406  with correct interpretation of S is put in cluster 374
#
# 	Pattern 410  with correct interpretation of S is put in cluster 374
#
# 	Pattern 417  with correct interpretation of S is put in cluster 374
#
# 	Pattern 421  with correct interpretation of S is put in cluster 374
#
# 	Pattern 433  with correct interpretation of S is put in cluster 374
#
# 	Pattern 434  with correct interpretation of S is put in cluster 374
#
# 	Pattern 459  with correct interpretation of S is put in cluster 374
#
# 	Pattern 466  with correct interpretation of O is put in cluster 374
#
# 	Pattern 478  with correct interpretation of O is put in cluster 374
#
# 	Pattern 487  with correct interpretation of S is put in cluster 374
#
# 	Pattern 490  with correct interpretation of S is put in cluster 374
#
# 	Pattern 491  with correct interpretation of S is put in cluster 374
# Cluster 48 with 62 patterns:
#
# 	Pattern 0  with correct interpretation of P is put in cluster 48
#
# 	Pattern 7  with correct interpretation of X is put in cluster 48
#
# 	Pattern 9  with correct interpretation of I is put in cluster 48
#
# 	Pattern 12  with correct interpretation of I is put in cluster 48
#
# 	Pattern 14  with correct interpretation of I is put in cluster 48
#
# 	Pattern 21  with correct interpretation of P is put in cluster 48
#
# 	Pattern 30  with correct interpretation of Z is put in cluster 48
#
# 	Pattern 31  with correct interpretation of I is put in cluster 48
#
# 	Pattern 32  with correct interpretation of X is put in cluster 48
#
# 	Pattern 45  with correct interpretation of I is put in cluster 48
#
# 	Pattern 53  with correct interpretation of I is put in cluster 48
#
# 	Pattern 59  with correct interpretation of I is put in cluster 48
#
# 	Pattern 62  with correct interpretation of I is put in cluster 48
#
# 	Pattern 67  with correct interpretation of I is put in cluster 48
#
# 	Pattern 70  with correct interpretation of I is put in cluster 48
#
# 	Pattern 75  with correct interpretation of I is put in cluster 48
#
# 	Pattern 80  with correct interpretation of I is put in cluster 48
#
# 	Pattern 90  with correct interpretation of I is put in cluster 48
#
# 	Pattern 114  with correct interpretation of I is put in cluster 48
#
# 	Pattern 119  with correct interpretation of I is put in cluster 48
#
# 	Pattern 124  with correct interpretation of I is put in cluster 48
#
# 	Pattern 131  with correct interpretation of I is put in cluster 48
#
# 	Pattern 192  with correct interpretation of I is put in cluster 48
#
# 	Pattern 194  with correct interpretation of I is put in cluster 48
#
# 	Pattern 207  with correct interpretation of I is put in cluster 48
#
# 	Pattern 210  with correct interpretation of I is put in cluster 48
#
# 	Pattern 220  with correct interpretation of I is put in cluster 48
#
# 	Pattern 223  with correct interpretation of I is put in cluster 48
#
# 	Pattern 224  with correct interpretation of X is put in cluster 48
#
# 	Pattern 233  with correct interpretation of I is put in cluster 48
#
# 	Pattern 243  with correct interpretation of I is put in cluster 48
#
# 	Pattern 250  with correct interpretation of I is put in cluster 48
#
# 	Pattern 256  with correct interpretation of I is put in cluster 48
#
# 	Pattern 266  with correct interpretation of I is put in cluster 48
#
# 	Pattern 267  with correct interpretation of I is put in cluster 48
#
# 	Pattern 268  with correct interpretation of I is put in cluster 48
#
# 	Pattern 288  with correct interpretation of I is put in cluster 48
#
# 	Pattern 315  with correct interpretation of I is put in cluster 48
#
# 	Pattern 318  with correct interpretation of I is put in cluster 48
#
# 	Pattern 323  with correct interpretation of I is put in cluster 48
#
# 	Pattern 326  with correct interpretation of I is put in cluster 48
#
# 	Pattern 330  with correct interpretation of I is put in cluster 48
#
# 	Pattern 356  with correct interpretation of I is put in cluster 48
#
# 	Pattern 360  with correct interpretation of P is put in cluster 48
#
# 	Pattern 362  with correct interpretation of I is put in cluster 48
#
# 	Pattern 377  with correct interpretation of I is put in cluster 48
#
# 	Pattern 394  with correct interpretation of I is put in cluster 48
#
# 	Pattern 401  with correct interpretation of P is put in cluster 48
#
# 	Pattern 402  with correct interpretation of I is put in cluster 48
#
# 	Pattern 404  with correct interpretation of X is put in cluster 48
#
# 	Pattern 405  with correct interpretation of Z is put in cluster 48
#
# 	Pattern 415  with correct interpretation of I is put in cluster 48
#
# 	Pattern 418  with correct interpretation of I is put in cluster 48
#
# 	Pattern 430  with correct interpretation of I is put in cluster 48
#
# 	Pattern 440  with correct interpretation of I is put in cluster 48
#
# 	Pattern 441  with correct interpretation of X is put in cluster 48
#
# 	Pattern 445  with correct interpretation of I is put in cluster 48
#
# 	Pattern 460  with correct interpretation of I is put in cluster 48
#
# 	Pattern 467  with correct interpretation of I is put in cluster 48
#
# 	Pattern 472  with correct interpretation of I is put in cluster 48
#
# 	Pattern 483  with correct interpretation of I is put in cluster 48
#
# 	Pattern 495  with correct interpretation of I is put in cluster 48
# Cluster 375 with 57 patterns:
#
# 	Pattern 3  with correct interpretation of U is put in cluster 375
#
# 	Pattern 29  with correct interpretation of P is put in cluster 375
#
# 	Pattern 41  with correct interpretation of P is put in cluster 375
#
# 	Pattern 44  with correct interpretation of P is put in cluster 375
#
# 	Pattern 52  with correct interpretation of P is put in cluster 375
#
# 	Pattern 84  with correct interpretation of P is put in cluster 375
#
# 	Pattern 89  with correct interpretation of P is put in cluster 375
#
# 	Pattern 95  with correct interpretation of U is put in cluster 375
#
# 	Pattern 108  with correct interpretation of U is put in cluster 375
#
# 	Pattern 109  with correct interpretation of P is put in cluster 375
#
# 	Pattern 137  with correct interpretation of P is put in cluster 375
#
# 	Pattern 138  with correct interpretation of U is put in cluster 375
#
# 	Pattern 147  with correct interpretation of P is put in cluster 375
#
# 	Pattern 160  with correct interpretation of U is put in cluster 375
#
# 	Pattern 182  with correct interpretation of C is put in cluster 375
#
# 	Pattern 196  with correct interpretation of P is put in cluster 375
#
# 	Pattern 208  with correct interpretation of X is put in cluster 375
#
# 	Pattern 213  with correct interpretation of P is put in cluster 375
#
# 	Pattern 217  with correct interpretation of U is put in cluster 375
#
# 	Pattern 227  with correct interpretation of U is put in cluster 375
#
# 	Pattern 235  with correct interpretation of P is put in cluster 375
#
# 	Pattern 236  with correct interpretation of P is put in cluster 375
#
# 	Pattern 238  with correct interpretation of P is put in cluster 375
#
# 	Pattern 245  with correct interpretation of P is put in cluster 375
#
# 	Pattern 253  with correct interpretation of P is put in cluster 375
#
# 	Pattern 280  with correct interpretation of P is put in cluster 375
#
# 	Pattern 283  with correct interpretation of P is put in cluster 375
#
# 	Pattern 285  with correct interpretation of P is put in cluster 375
#
# 	Pattern 287  with correct interpretation of U is put in cluster 375
#
# 	Pattern 290  with correct interpretation of P is put in cluster 375
#
# 	Pattern 291  with correct interpretation of X is put in cluster 375
#
# 	Pattern 293  with correct interpretation of X is put in cluster 375
#
# 	Pattern 295  with correct interpretation of U is put in cluster 375
#
# 	Pattern 300  with correct interpretation of P is put in cluster 375
#
# 	Pattern 321  with correct interpretation of P is put in cluster 375
#
# 	Pattern 325  with correct interpretation of P is put in cluster 375
#
# 	Pattern 341  with correct interpretation of U is put in cluster 375
#
# 	Pattern 345  with correct interpretation of Z is put in cluster 375
#
# 	Pattern 347  with correct interpretation of P is put in cluster 375
#
# 	Pattern 350  with correct interpretation of P is put in cluster 375
#
# 	Pattern 370  with correct interpretation of P is put in cluster 375
#
# 	Pattern 371  with correct interpretation of P is put in cluster 375
#
# 	Pattern 373  with correct interpretation of P is put in cluster 375
#
# 	Pattern 374  with correct interpretation of U is put in cluster 375
#
# 	Pattern 375  with correct interpretation of U is put in cluster 375
#
# 	Pattern 378  with correct interpretation of P is put in cluster 375
#
# 	Pattern 380  with correct interpretation of P is put in cluster 375
#
# 	Pattern 388  with correct interpretation of P is put in cluster 375
#
# 	Pattern 409  with correct interpretation of Z is put in cluster 375
#
# 	Pattern 413  with correct interpretation of P is put in cluster 375
#
# 	Pattern 420  with correct interpretation of P is put in cluster 375
#
# 	Pattern 444  with correct interpretation of P is put in cluster 375
#
# 	Pattern 446  with correct interpretation of P is put in cluster 375
#
# 	Pattern 454  with correct interpretation of P is put in cluster 375
#
# 	Pattern 476  with correct interpretation of U is put in cluster 375
#
# 	Pattern 481  with correct interpretation of P is put in cluster 375
#
# 	Pattern 486  with correct interpretation of P is put in cluster 375
# Cluster 143 with 23 patterns:
#
# 	Pattern 27  with correct interpretation of Z is put in cluster 143
#
# 	Pattern 92  with correct interpretation of U is put in cluster 143
#
# 	Pattern 96  with correct interpretation of U is put in cluster 143
#
# 	Pattern 116  with correct interpretation of Z is put in cluster 143
#
# 	Pattern 149  with correct interpretation of U is put in cluster 143
#
# 	Pattern 152  with correct interpretation of U is put in cluster 143
#
# 	Pattern 172  with correct interpretation of P is put in cluster 143
#
# 	Pattern 177  with correct interpretation of Z is put in cluster 143
#
# 	Pattern 188  with correct interpretation of U is put in cluster 143
#
# 	Pattern 195  with correct interpretation of U is put in cluster 143
#
# 	Pattern 199  with correct interpretation of Z is put in cluster 143
#
# 	Pattern 201  with correct interpretation of C is put in cluster 143
#
# 	Pattern 226  with correct interpretation of C is put in cluster 143
#
# 	Pattern 242  with correct interpretation of U is put in cluster 143
#
# 	Pattern 262  with correct interpretation of Z is put in cluster 143
#
# 	Pattern 264  with correct interpretation of U is put in cluster 143
#
# 	Pattern 278  with correct interpretation of U is put in cluster 143
#
# 	Pattern 282  with correct interpretation of Z is put in cluster 143
#
# 	Pattern 307  with correct interpretation of U is put in cluster 143
#
# 	Pattern 332  with correct interpretation of U is put in cluster 143
#
# 	Pattern 349  with correct interpretation of X is put in cluster 143
#
# 	Pattern 450  with correct interpretation of Z is put in cluster 143
#
# 	Pattern 464  with correct interpretation of U is put in cluster 143
# Cluster 478 with 22 patterns:
#
# 	Pattern 4  with correct interpretation of Z is put in cluster 478
#
# 	Pattern 17  with correct interpretation of P is put in cluster 478
#
# 	Pattern 20  with correct interpretation of U is put in cluster 478
#
# 	Pattern 50  with correct interpretation of C is put in cluster 478
#
# 	Pattern 74  with correct interpretation of C is put in cluster 478
#
# 	Pattern 91  with correct interpretation of P is put in cluster 478
#
# 	Pattern 121  with correct interpretation of C is put in cluster 478
#
# 	Pattern 126  with correct interpretation of P is put in cluster 478
#
# 	Pattern 166  with correct interpretation of O is put in cluster 478
#
# 	Pattern 190  with correct interpretation of C is put in cluster 478
#
# 	Pattern 191  with correct interpretation of Z is put in cluster 478
#
# 	Pattern 232  with correct interpretation of C is put in cluster 478
#
# 	Pattern 254  with correct interpretation of U is put in cluster 478
#
# 	Pattern 348  with correct interpretation of C is put in cluster 478
#
# 	Pattern 392  with correct interpretation of U is put in cluster 478
#
# 	Pattern 422  with correct interpretation of P is put in cluster 478
#
# 	Pattern 425  with correct interpretation of S is put in cluster 478
#
# 	Pattern 427  with correct interpretation of P is put in cluster 478
#
# 	Pattern 435  with correct interpretation of Z is put in cluster 478
#
# 	Pattern 443  with correct interpretation of C is put in cluster 478
#
# 	Pattern 463  with correct interpretation of C is put in cluster 478
#
# 	Pattern 482  with correct interpretation of Z is put in cluster 478
# Cluster 318 with 20 patterns:
#
# 	Pattern 24  with correct interpretation of X is put in cluster 318
#
# 	Pattern 28  with correct interpretation of Z is put in cluster 318
#
# 	Pattern 33  with correct interpretation of Z is put in cluster 318
#
# 	Pattern 55  with correct interpretation of U is put in cluster 318
#
# 	Pattern 85  with correct interpretation of S is put in cluster 318
#
# 	Pattern 110  with correct interpretation of C is put in cluster 318
#
# 	Pattern 129  with correct interpretation of C is put in cluster 318
#
# 	Pattern 133  with correct interpretation of U is put in cluster 318
#
# 	Pattern 139  with correct interpretation of I is put in cluster 318
#
# 	Pattern 146  with correct interpretation of Z is put in cluster 318
#
# 	Pattern 163  with correct interpretation of P is put in cluster 318
#
# 	Pattern 174  with correct interpretation of X is put in cluster 318
#
# 	Pattern 211  with correct interpretation of C is put in cluster 318
#
# 	Pattern 214  with correct interpretation of Z is put in cluster 318
#
# 	Pattern 265  with correct interpretation of X is put in cluster 318
#
# 	Pattern 355  with correct interpretation of I is put in cluster 318
#
# 	Pattern 364  with correct interpretation of U is put in cluster 318
#
# 	Pattern 365  with correct interpretation of P is put in cluster 318
#
# 	Pattern 469  with correct interpretation of C is put in cluster 318
#
# 	Pattern 480  with correct interpretation of U is put in cluster 318
# Cluster 513 with 1 patterns:
#
# 	Pattern 79  with correct interpretation of U is put in cluster 513
# Cluster 624 with 0 patterns:
# Cluster 208 with 0 patterns:
# Cluster 207 with 0 patterns:
# Cluster 206 with 0 patterns:
# Cluster 205 with 0 patterns:
# Cluster 203 with 0 patterns:
# Cluster 204 with 0 patterns:
# Cluster 210 with 0 patterns:
# Cluster 202 with 0 patterns:
# Cluster 201 with 0 patterns:

# %%
#np.save('initial_weight.npy', initial_weight)
#np.save('final_weight.npy', weight)
#initial_weight = np.load('initial_weight.npy')
#weight = np.load('final_weight.npy')
