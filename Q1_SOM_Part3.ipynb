# %% [markdown]
# <a href="https://colab.research.google.com/github/m3y54m/ut-nndl-course/blob/master/Q1_SOM_Part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# http://mnemstudio.org/neural-networks-kohonen-self-organizing-maps.htm
# https://www.saedsayad.com/clustering_som.htm
# Packages and libraries used in this program
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset with labels
#raw_data = np.load('Alphabets.npy').astype(float)
#labels = np.load('Alphabet_labels.npy')
alphabets =  np.array(['C','I','O','P','S','U','X','Z'])
#initial_weight = np.load('initial_weight.npy')

# %%
from google.colab import files
import io
uploaded = files.upload()
raw_data = np.load(io.BytesIO(uploaded['Alphabets.npy'])).astype(float)
uploaded = files.upload()
labels = np.load(io.BytesIO(uploaded['Alphabet_labels.npy']))
uploaded = files.upload()
initial_weight = np.load(io.BytesIO(uploaded['initial_weight.npy']))
# Out:
#      <input type="file" id="files-35449939-0a04-4a52-8822-78e5b7267c93" name="files[]" multiple disabled />
#      <output id="result-35449939-0a04-4a52-8822-78e5b7267c93">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alphabets.npy to Alphabets (2).npy
#      <input type="file" id="files-cf58f609-083b-4af3-aa4a-ef2a9eb70360" name="files[]" multiple disabled />
#      <output id="result-cf58f609-083b-4af3-aa4a-ef2a9eb70360">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alphabet_labels.npy to Alphabet_labels (2).npy
#      <input type="file" id="files-a567783a-0c1b-4d3b-9d21-1c056d512654" name="files[]" multiple disabled />
#      <output id="result-a567783a-0c1b-4d3b-9d21-1c056d512654">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving initial_weight.npy to initial_weight (2).npy

# %%
# Number of neurons (2-dimensional)
# 625 = 25 * 25
M = 625 

# Dimension of the input patterns
N = raw_data.shape[1]

# Total number of input patterns
P = raw_data.shape[0]

learning_rate = 0.3

R = 1

MAX_EPOCHS = 100

MAX_WEIGHT_DIFF = 0.0001

DECAY_FACTOR = 0.0001

RADIUS_REDUCTION_STEP = 200

np.set_printoptions(threshold=np.nan)

# %%
# Normalize input vectors
sc = MinMaxScaler(feature_range = (0, 1))
data = sc.fit_transform(raw_data)

# %%
# Step 1: Initialization of each node’s weights with a random number between 0 and 1
#weight = 0.1 * np.random.rand(N,M)
weight = np.copy(initial_weight)
#print("Initial weights:")
#print(np.around(weight, 2))

last_weight = np.copy(weight)

for epoch in range(MAX_EPOCHS):
    print("\r\nEpoch:", epoch)
    print("Learning rate:", np.around(learning_rate, 6))
    print("Neighborhood radius:", R)
    
    # Step 2: Choosing input patterns ordering
    # use normal ordering
    pattern_ordering = np.arange(P)
    # use random ordering
    #np.random.shuffle(pattern_ordering)
    #print("Random input patterns ordering:", pattern_ordering)
    
    progress = 0
    
    # For each input pattern do the steps 3-5
    for p in pattern_ordering:
        
        progress = progress + 1
        
        #print("\r\n\tCurrent pattern index is", p, "and", np.around(progress/P*100, 2), "% of patterns has been processed in Epoch", epoch)
        
        # Step 3: Calculating the Best Matching Unit (BMU)

        # initialize distance vector
        distance_vector = np.zeros(M)
    
        # calculate distance of each weight from each input pattern
        for j in range(M):
            for i in range(N):
                distance_vector[j] = distance_vector[j] + (weight[i,j] - data[p,i])**2
                
        #print("\tdistance_vector", np.around(distance_vector, 2))

        # Step 4: find index j such that distance_vector[j] is a minimum
        min_distance_index = np.argmin(distance_vector)
        # calculate m = SQRT( M )
        m = np.sqrt(M).astype(int)
        min_distance_index_j = (min_distance_index % m).astype(int)
        min_distance_index_k = np.floor(min_distance_index / m).astype(int)
        
        
        #print("\tmin_distance_index", min_distance_index)
        #print("\tmin_distance_index j", min_distance_index_j)
        #print("\tmin_distance_index k", min_distance_index_k)
        
        # Step 5: Update weights for all units j within a specified neighberhood of min_distance_index and for all i
        # calculate neighborhood borders
        begin_j = min_distance_index_j - R
        if (begin_j < 0):
            begin_j = 0
        
        end_j = min_distance_index_j + R
        if (end_j > m - 1):
            end_j = m - 1
        
        begin_k = min_distance_index_k - R
        if (begin_k < 0):
            begin_k = 0
        
        end_k = min_distance_index_k + R
        if (end_k > m - 1):
            end_k = m - 1
        
        #print("neighberhood j", begin_j, end_j)
        #print("neighberhood k", begin_k, end_k)
        
        for j in range(begin_j, end_j + 1):
            for k in range(begin_k, end_k + 1):
                for i in range(N):
                    weight[i,j + m*k] = weight[i,j + m*k] + learning_rate * (data[p,i] - weight[i,j + m*k])

    # Step 6: Update learning rate
    learning_rate = DECAY_FACTOR * learning_rate

    # Step 7: Reduce radius of topological neighborhood at specified times
    if (epoch % RADIUS_REDUCTION_STEP):
        if R > 0 :
            R = R - 1
        
    # Step 8: Test stopping condition
    weight_diff = np.amax(np.abs(weight - last_weight))
    
    if (weight_diff < MAX_WEIGHT_DIFF):
        print("Weight change:", weight_diff, "<", MAX_WEIGHT_DIFF)
        print("Stopping condition is satisfied!")
        break
    else:
        print("Weight change:", weight_diff, ">", MAX_WEIGHT_DIFF)
    
    last_weight = np.copy(weight)
    # end of for loop
    
#print("\r\Final weights:")
#print(np.around(weight, 2))
# Out:
# Epoch: 0
# Learning rate: 0.3
# Neighborhood radius: 1
# Weight change: 0.9882485881315936 > 0.0001
#
# Epoch: 1
# Learning rate: 3e-05
# Neighborhood radius: 1
# Weight change: 0.0006175155916391395 > 0.0001
#
# Epoch: 2
# Learning rate: 0.0
# Neighborhood radius: 0
# Weight change: 1.7951432784713006e-08 < 0.0001
# Stopping condition is satisfied!

# %%
# associate pattern indices with clusters numbers
patterns_with_clusters = np.zeros((P, 2), dtype=int)

for p in range(P):

    distance_vector = np.zeros(M)

    # calculate distance of each weight from each input pattern
    for j in range(M):
        for i in range(N):
            distance_vector[j] = distance_vector[j] + (weight[i,j] - data[p,i])**2

    # find index j such that distance_vector[j] is a minimum
    min_distance_index = np.argmin(distance_vector)
    
    # store pattern index 
    patterns_with_clusters[p,0] = p
    # store cluster number associated with pattern 
    patterns_with_clusters[p,1] = min_distance_index

# %%
# make an array of clusters size and members
clusters_size = [0 for j in range(M)]
clusters_members = [[] for j in range(M)]
for p in range(P):
    # increment cluster size by 1
    clusters_size[patterns_with_clusters[p,1].astype(int)] = clusters_size[patterns_with_clusters[p,1].astype(int)] + 1
    # append the pattern index to cluster members list
    clusters_members[patterns_with_clusters[p,1].astype(int)].append(p)


clustered_patterns = [clusters_size, clusters_members]

# find 20 largest clusters
largest_clusters = np.asarray(clusters_size).argsort()[-20:][::-1]

print("20 Largest Clusters")
total_of_20 = 0
for j in largest_clusters:
    print("Cluster", j, "\t=>\t", clusters_size[j],"patterns.")
    total_of_20 = total_of_20 + clusters_size[j]
print("\r\nTotal", total_of_20, "patterns are in top 20 clusters.")
# Out:
# 20 Largest Clusters
# Cluster 0 	=>	 12 patterns.
# Cluster 250 	=>	 12 patterns.
# Cluster 6 	=>	 11 patterns.
# Cluster 54 	=>	 10 patterns.
# Cluster 153 	=>	 10 patterns.
# Cluster 3 	=>	 10 patterns.
# Cluster 280 	=>	 9 patterns.
# Cluster 251 	=>	 9 patterns.
# Cluster 259 	=>	 9 patterns.
# Cluster 303 	=>	 9 patterns.
# Cluster 110 	=>	 9 patterns.
# Cluster 130 	=>	 8 patterns.
# Cluster 225 	=>	 8 patterns.
# Cluster 128 	=>	 7 patterns.
# Cluster 281 	=>	 7 patterns.
# Cluster 255 	=>	 7 patterns.
# Cluster 235 	=>	 7 patterns.
# Cluster 231 	=>	 7 patterns.
# Cluster 2 	=>	 7 patterns.
# Cluster 180 	=>	 7 patterns.
#
# Total 175 patterns are in top 20 clusters.

# %%
original_data = sc.inverse_transform(data)
clusters_size = clustered_patterns[0]
clusters_members = clustered_patterns[1]
for j in largest_clusters:
    print("Cluster", j, "with", clusters_size[j],"patterns:")
    for p in clusters_members[j]:
        print("\r\n\tPattern", p, " with correct interpretation of", alphabets[labels[p]] ,"is put in cluster", j)
        #plt.imshow(original_data[p].reshape(28,28))
        #plt.show()
# Out:
# Cluster 0 with 12 patterns:
#
# 	Pattern 48  with correct interpretation of U is put in cluster 0
#
# 	Pattern 61  with correct interpretation of U is put in cluster 0
#
# 	Pattern 79  with correct interpretation of U is put in cluster 0
#
# 	Pattern 104  with correct interpretation of U is put in cluster 0
#
# 	Pattern 120  with correct interpretation of U is put in cluster 0
#
# 	Pattern 143  with correct interpretation of U is put in cluster 0
#
# 	Pattern 261  with correct interpretation of U is put in cluster 0
#
# 	Pattern 308  with correct interpretation of U is put in cluster 0
#
# 	Pattern 309  with correct interpretation of U is put in cluster 0
#
# 	Pattern 314  with correct interpretation of U is put in cluster 0
#
# 	Pattern 357  with correct interpretation of U is put in cluster 0
#
# 	Pattern 436  with correct interpretation of U is put in cluster 0
# Cluster 250 with 12 patterns:
#
# 	Pattern 74  with correct interpretation of C is put in cluster 250
#
# 	Pattern 84  with correct interpretation of P is put in cluster 250
#
# 	Pattern 89  with correct interpretation of P is put in cluster 250
#
# 	Pattern 137  with correct interpretation of P is put in cluster 250
#
# 	Pattern 235  with correct interpretation of P is put in cluster 250
#
# 	Pattern 245  with correct interpretation of P is put in cluster 250
#
# 	Pattern 280  with correct interpretation of P is put in cluster 250
#
# 	Pattern 347  with correct interpretation of P is put in cluster 250
#
# 	Pattern 388  with correct interpretation of P is put in cluster 250
#
# 	Pattern 413  with correct interpretation of P is put in cluster 250
#
# 	Pattern 420  with correct interpretation of P is put in cluster 250
#
# 	Pattern 446  with correct interpretation of P is put in cluster 250
# Cluster 6 with 11 patterns:
#
# 	Pattern 60  with correct interpretation of U is put in cluster 6
#
# 	Pattern 95  with correct interpretation of U is put in cluster 6
#
# 	Pattern 108  with correct interpretation of U is put in cluster 6
#
# 	Pattern 160  with correct interpretation of U is put in cluster 6
#
# 	Pattern 195  with correct interpretation of U is put in cluster 6
#
# 	Pattern 217  with correct interpretation of U is put in cluster 6
#
# 	Pattern 287  with correct interpretation of U is put in cluster 6
#
# 	Pattern 295  with correct interpretation of U is put in cluster 6
#
# 	Pattern 341  with correct interpretation of U is put in cluster 6
#
# 	Pattern 364  with correct interpretation of U is put in cluster 6
#
# 	Pattern 407  with correct interpretation of U is put in cluster 6
# Cluster 54 with 10 patterns:
#
# 	Pattern 26  with correct interpretation of C is put in cluster 54
#
# 	Pattern 46  with correct interpretation of O is put in cluster 54
#
# 	Pattern 86  with correct interpretation of O is put in cluster 54
#
# 	Pattern 103  with correct interpretation of O is put in cluster 54
#
# 	Pattern 178  with correct interpretation of O is put in cluster 54
#
# 	Pattern 181  with correct interpretation of O is put in cluster 54
#
# 	Pattern 189  with correct interpretation of O is put in cluster 54
#
# 	Pattern 216  with correct interpretation of O is put in cluster 54
#
# 	Pattern 218  with correct interpretation of O is put in cluster 54
#
# 	Pattern 424  with correct interpretation of O is put in cluster 54
# Cluster 153 with 10 patterns:
#
# 	Pattern 78  with correct interpretation of S is put in cluster 153
#
# 	Pattern 87  with correct interpretation of S is put in cluster 153
#
# 	Pattern 122  with correct interpretation of S is put in cluster 153
#
# 	Pattern 252  with correct interpretation of S is put in cluster 153
#
# 	Pattern 328  with correct interpretation of S is put in cluster 153
#
# 	Pattern 359  with correct interpretation of S is put in cluster 153
#
# 	Pattern 369  with correct interpretation of S is put in cluster 153
#
# 	Pattern 410  with correct interpretation of S is put in cluster 153
#
# 	Pattern 417  with correct interpretation of S is put in cluster 153
#
# 	Pattern 425  with correct interpretation of S is put in cluster 153
# Cluster 3 with 10 patterns:
#
# 	Pattern 51  with correct interpretation of U is put in cluster 3
#
# 	Pattern 68  with correct interpretation of U is put in cluster 3
#
# 	Pattern 150  with correct interpretation of C is put in cluster 3
#
# 	Pattern 173  with correct interpretation of U is put in cluster 3
#
# 	Pattern 206  with correct interpretation of U is put in cluster 3
#
# 	Pattern 228  with correct interpretation of U is put in cluster 3
#
# 	Pattern 374  with correct interpretation of U is put in cluster 3
#
# 	Pattern 375  with correct interpretation of U is put in cluster 3
#
# 	Pattern 451  with correct interpretation of U is put in cluster 3
#
# 	Pattern 476  with correct interpretation of U is put in cluster 3
# Cluster 280 with 9 patterns:
#
# 	Pattern 14  with correct interpretation of I is put in cluster 280
#
# 	Pattern 31  with correct interpretation of I is put in cluster 280
#
# 	Pattern 53  with correct interpretation of I is put in cluster 280
#
# 	Pattern 59  with correct interpretation of I is put in cluster 280
#
# 	Pattern 67  with correct interpretation of I is put in cluster 280
#
# 	Pattern 90  with correct interpretation of I is put in cluster 280
#
# 	Pattern 114  with correct interpretation of I is put in cluster 280
#
# 	Pattern 356  with correct interpretation of I is put in cluster 280
#
# 	Pattern 394  with correct interpretation of I is put in cluster 280
# Cluster 251 with 9 patterns:
#
# 	Pattern 17  with correct interpretation of P is put in cluster 251
#
# 	Pattern 41  with correct interpretation of P is put in cluster 251
#
# 	Pattern 238  with correct interpretation of P is put in cluster 251
#
# 	Pattern 253  with correct interpretation of P is put in cluster 251
#
# 	Pattern 255  with correct interpretation of O is put in cluster 251
#
# 	Pattern 283  with correct interpretation of P is put in cluster 251
#
# 	Pattern 285  with correct interpretation of P is put in cluster 251
#
# 	Pattern 300  with correct interpretation of P is put in cluster 251
#
# 	Pattern 454  with correct interpretation of P is put in cluster 251
# Cluster 259 with 9 patterns:
#
# 	Pattern 7  with correct interpretation of X is put in cluster 259
#
# 	Pattern 27  with correct interpretation of Z is put in cluster 259
#
# 	Pattern 33  with correct interpretation of Z is put in cluster 259
#
# 	Pattern 92  with correct interpretation of U is put in cluster 259
#
# 	Pattern 133  with correct interpretation of U is put in cluster 259
#
# 	Pattern 177  with correct interpretation of Z is put in cluster 259
#
# 	Pattern 278  with correct interpretation of U is put in cluster 259
#
# 	Pattern 282  with correct interpretation of Z is put in cluster 259
#
# 	Pattern 291  with correct interpretation of X is put in cluster 259
# Cluster 303 with 9 patterns:
#
# 	Pattern 80  with correct interpretation of I is put in cluster 303
#
# 	Pattern 139  with correct interpretation of I is put in cluster 303
#
# 	Pattern 194  with correct interpretation of I is put in cluster 303
#
# 	Pattern 220  with correct interpretation of I is put in cluster 303
#
# 	Pattern 243  with correct interpretation of I is put in cluster 303
#
# 	Pattern 288  with correct interpretation of I is put in cluster 303
#
# 	Pattern 430  with correct interpretation of I is put in cluster 303
#
# 	Pattern 445  with correct interpretation of I is put in cluster 303
#
# 	Pattern 495  with correct interpretation of I is put in cluster 303
# Cluster 110 with 9 patterns:
#
# 	Pattern 168  with correct interpretation of O is put in cluster 110
#
# 	Pattern 226  with correct interpretation of C is put in cluster 110
#
# 	Pattern 230  with correct interpretation of C is put in cluster 110
#
# 	Pattern 247  with correct interpretation of C is put in cluster 110
#
# 	Pattern 258  with correct interpretation of O is put in cluster 110
#
# 	Pattern 276  with correct interpretation of C is put in cluster 110
#
# 	Pattern 304  with correct interpretation of C is put in cluster 110
#
# 	Pattern 305  with correct interpretation of C is put in cluster 110
#
# 	Pattern 432  with correct interpretation of O is put in cluster 110
# Cluster 130 with 8 patterns:
#
# 	Pattern 6  with correct interpretation of U is put in cluster 130
#
# 	Pattern 128  with correct interpretation of C is put in cluster 130
#
# 	Pattern 149  with correct interpretation of U is put in cluster 130
#
# 	Pattern 158  with correct interpretation of U is put in cluster 130
#
# 	Pattern 269  with correct interpretation of O is put in cluster 130
#
# 	Pattern 439  with correct interpretation of C is put in cluster 130
#
# 	Pattern 458  with correct interpretation of C is put in cluster 130
#
# 	Pattern 464  with correct interpretation of U is put in cluster 130
# Cluster 225 with 8 patterns:
#
# 	Pattern 29  with correct interpretation of P is put in cluster 225
#
# 	Pattern 213  with correct interpretation of P is put in cluster 225
#
# 	Pattern 236  with correct interpretation of P is put in cluster 225
#
# 	Pattern 290  with correct interpretation of P is put in cluster 225
#
# 	Pattern 370  with correct interpretation of P is put in cluster 225
#
# 	Pattern 373  with correct interpretation of P is put in cluster 225
#
# 	Pattern 380  with correct interpretation of P is put in cluster 225
#
# 	Pattern 419  with correct interpretation of P is put in cluster 225
# Cluster 128 with 7 patterns:
#
# 	Pattern 76  with correct interpretation of S is put in cluster 128
#
# 	Pattern 81  with correct interpretation of S is put in cluster 128
#
# 	Pattern 219  with correct interpretation of S is put in cluster 128
#
# 	Pattern 298  with correct interpretation of S is put in cluster 128
#
# 	Pattern 366  with correct interpretation of S is put in cluster 128
#
# 	Pattern 434  with correct interpretation of S is put in cluster 128
#
# 	Pattern 490  with correct interpretation of S is put in cluster 128
# Cluster 281 with 7 patterns:
#
# 	Pattern 62  with correct interpretation of I is put in cluster 281
#
# 	Pattern 250  with correct interpretation of I is put in cluster 281
#
# 	Pattern 267  with correct interpretation of I is put in cluster 281
#
# 	Pattern 315  with correct interpretation of I is put in cluster 281
#
# 	Pattern 318  with correct interpretation of I is put in cluster 281
#
# 	Pattern 402  with correct interpretation of I is put in cluster 281
#
# 	Pattern 467  with correct interpretation of I is put in cluster 281
# Cluster 255 with 7 patterns:
#
# 	Pattern 9  with correct interpretation of I is put in cluster 255
#
# 	Pattern 75  with correct interpretation of I is put in cluster 255
#
# 	Pattern 119  with correct interpretation of I is put in cluster 255
#
# 	Pattern 210  with correct interpretation of I is put in cluster 255
#
# 	Pattern 323  with correct interpretation of I is put in cluster 255
#
# 	Pattern 330  with correct interpretation of I is put in cluster 255
#
# 	Pattern 404  with correct interpretation of X is put in cluster 255
# Cluster 235 with 7 patterns:
#
# 	Pattern 96  with correct interpretation of U is put in cluster 235
#
# 	Pattern 110  with correct interpretation of C is put in cluster 235
#
# 	Pattern 152  with correct interpretation of U is put in cluster 235
#
# 	Pattern 199  with correct interpretation of Z is put in cluster 235
#
# 	Pattern 307  with correct interpretation of U is put in cluster 235
#
# 	Pattern 332  with correct interpretation of U is put in cluster 235
#
# 	Pattern 450  with correct interpretation of Z is put in cluster 235
# Cluster 231 with 7 patterns:
#
# 	Pattern 2  with correct interpretation of X is put in cluster 231
#
# 	Pattern 13  with correct interpretation of X is put in cluster 231
#
# 	Pattern 208  with correct interpretation of X is put in cluster 231
#
# 	Pattern 385  with correct interpretation of I is put in cluster 231
#
# 	Pattern 412  with correct interpretation of X is put in cluster 231
#
# 	Pattern 428  with correct interpretation of X is put in cluster 231
#
# 	Pattern 447  with correct interpretation of X is put in cluster 231
# Cluster 2 with 7 patterns:
#
# 	Pattern 10  with correct interpretation of U is put in cluster 2
#
# 	Pattern 15  with correct interpretation of U is put in cluster 2
#
# 	Pattern 93  with correct interpretation of U is put in cluster 2
#
# 	Pattern 162  with correct interpretation of U is put in cluster 2
#
# 	Pattern 372  with correct interpretation of U is put in cluster 2
#
# 	Pattern 399  with correct interpretation of U is put in cluster 2
#
# 	Pattern 411  with correct interpretation of U is put in cluster 2
# Cluster 180 with 7 patterns:
#
# 	Pattern 132  with correct interpretation of Z is put in cluster 180
#
# 	Pattern 141  with correct interpretation of Z is put in cluster 180
#
# 	Pattern 200  with correct interpretation of Z is put in cluster 180
#
# 	Pattern 234  with correct interpretation of Z is put in cluster 180
#
# 	Pattern 313  with correct interpretation of Z is put in cluster 180
#
# 	Pattern 396  with correct interpretation of Z is put in cluster 180
#
# 	Pattern 498  with correct interpretation of Z is put in cluster 180

# %%
#np.save('initial_weight.npy', initial_weight)
#np.save('final_weight.npy', weight)
#initial_weight = np.load('initial_weight.npy')
#weight = np.load('final_weight.npy')
